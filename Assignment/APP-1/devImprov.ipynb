# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

from scipy.stats import chi2_contingency
from scipy import stats

from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
def create_new_features(df):
    # Timing features
    # df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    # df['hour'] = df['Timestamp'].dt.hour
    # df['minute'] = df['Timestamp'].dt.minute
    # df['day_of_week'] = df['Timestamp'].dt.dayofweek
    # df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)
    
    # IP-based features
    def ip_to_int(ip):
        try:
            parts = [int(part) for part in ip.split('.')]
            return parts[0] * 256**3 + parts[1] * 256**2 + parts[2] * 256 + parts[3]
        except:
            return 0
    
    non_numeric_cols = ['Protocol']
    for col in non_numeric_cols:
        combined_values = pd.concat([train_df[col], test_df[col]], axis=0).astype(str).unique()
        train_df[col] = pd.Categorical(train_df[col], categories=combined_values).codes
        test_df[col] = pd.Categorical(test_df[col], categories=combined_values).codes
    
    # df['Source_IP_num'] = df['Source_IP'].apply(ip_to_int)
    # df['Destination_IP_num'] = df['Destination_IP'].apply(ip_to_int)
    
    # Packet statistics
    df['packets_ratio'] = df['fwd_packets_amount'] / (df['bwd_packets_amount'] + 1)
    df['bytes_ratio'] = df['fwd_packets_length'] / (df['bwd_packets_length'] + 1)
    df['total_packets'] = df['fwd_packets_amount'] + df['bwd_packets_amount']
    df['total_bytes'] = df['fwd_packets_length'] + df['bwd_packets_length']
    df['avg_fwd_packet_size'] = df['fwd_packets_length'] / (df['fwd_packets_amount'] + 1)
    df['avg_bwd_packet_size'] = df['bwd_packets_length'] / (df['bwd_packets_amount'] + 1)
    
    # Flag combinations
    df['total_flags'] = df['FIN_count'] + df['SYN_count'] + df['RST_count'] + df['PSH_count']
    
    # Inter-arrival time statistics
    df['fwd_iat_mean'] = df['mean_fwd_inter_arrival_time']
    df['bwd_iat_mean'] = df['mean_bwd_inter_arrival_time']
    df['iat_ratio'] = df['fwd_iat_mean'] / (df['bwd_iat_mean'] + 1)
    
    # Packet size patterns
    packet_size_cols = [col for col in df.columns if col.startswith('first_packet_sizes_')]
    df['mean_first_packet_size'] = df[packet_size_cols].mean(axis=1)
    df['std_first_packet_size'] = df[packet_size_cols].std(axis=1)
    df['max_first_packet_size'] = df[packet_size_cols].max(axis=1)
    df['min_first_packet_size'] = df[packet_size_cols].min(axis=1)
    
    # Bandwidth features
    bandwidth_cols = [col for col in df.columns if col.startswith('bandwidth_')]
    df['mean_bandwidth'] = df[bandwidth_cols].mean(axis=1)
    df['std_bandwidth'] = df[bandwidth_cols].std(axis=1)
    df['max_bandwidth'] = df[bandwidth_cols].max(axis=1)
    # df['bandwidth_sum'] = df[bandwidth_cols].sum(axis=1)  # New column for bandwidth sum
    
    return df

# %%
print("Loading datasets...")
train_df = pd.read_csv(r"C:\Users\חנן\Desktop\אריאל אונ'\שנה ג\זיהוי התקפות\תרגיל\תרגיל\APP-1\Train.csv")
test_df = pd.read_csv(r"C:\Users\חנן\Desktop\אריאל אונ'\שנה ג\זיהוי התקפות\תרגיל\תרגיל\APP-1\Test.csv")
# Out:
# Loading datasets...

# %%
# train_df

# %%
# Separate features and target
target_column = train_df['label']  # Assuming 'label' is the last column

train_df_processed = create_new_features(train_df)
test_df_processed = create_new_features(test_df)

X = train_df_processed.drop(columns=['label'])  # X = all columns except the last. This is our features
y = train_df_processed['label']  # y = last column. This is our target.

# %%
# # Separate features and target
# target_column = train_df.columns[-1]  # Assuming 'label' is the last column

# X = train_df.drop(columns=[target_column])  # X = all columns except the last. This is our features
# y = train_df[target_column]  # y = last column. This is our target.

# %%
categorical_columns = X.select_dtypes(include=['object']).columns  # Select object type columns
print(f"Found {len(categorical_columns)} categorical columns: {list(categorical_columns)}")
# Out:
# Found 2 categorical columns: ['Source_IP', 'Destination_IP']

# %%
# Initialize label encoders dictionary
label_encoders = {}

# Encode categorical columns
for col in categorical_columns:
    print(f"\nEncoding column: {col}")
    print(f"Original unique values: {X[col].nunique()}")
    
    le = LabelEncoder()
    # Combine train and test data for encoding
    combined_data = pd.concat([X[col], test_df[col]])
    le.fit(combined_data.astype(str))
    
    # Transform both training and test data
    X[col] = le.transform(X[col].astype(str))
    test_df[col] = le.transform(test_df[col].astype(str))
    
    label_encoders[col] = le
    print(f"Encoded unique values: {len(le.classes_)}")
# Out:
# Encoding column: Source_IP
# Original unique values: 8
# Encoded unique values: 9
#
# Encoding column: Destination_IP
# Original unique values: 330
# Encoded unique values: 468

# %%
# Let's handle the encoding more carefully
categorical_columns = []
for column in X.columns:
    # Check if column contains any non-numeric values
    if not pd.to_numeric(X[column], errors='coerce').notnull().all() or \
       not pd.to_numeric(test_df[column], errors='coerce').notnull().all():
        categorical_columns.append(column)

print("\nIdentified categorical columns:", categorical_columns)
# Out:
# Identified categorical columns: []

# %%
# Encode categorical columns
label_encoders = {}
for col in categorical_columns:
    print(f"\nProcessing column: {col}")
    le = LabelEncoder()
    # Combine unique values from both train and test
    combined_values = pd.concat([X[col], test_df[col]]).unique()
    le.fit(combined_values.astype(str))
    
    # Transform the data
    X[col] = le.transform(X[col].astype(str))
    test_df[col] = le.transform(test_df[col].astype(str))
    
    label_encoders[col] = le
    print(f"Encoded {col}: {len(le.classes_)} unique values")

# %%
# Now try converting to float again
try:
    X = X.astype(float)
    print("\nSuccessfully converted training data to float")
except ValueError as e:
    print("\nError in converting training data:", e)
    
try:
    test_df = test_df.astype(float)
    print("Successfully converted test data to float")
except ValueError as e:
    print("\nError in converting test data:", e)
# Out:
# Successfully converted training data to float
#
# Error in converting test data: could not convert string to float: '1inch.io'

# %%
# Verify final data types
print("\nFinal data types - Training:")
print(X.dtypes.value_counts())
print("\nFinal data types - Test:")
print(test_df.dtypes.value_counts())

# Additional verification step
print("\nVerifying no remaining string values:")
for column in X.columns:
    try:
        X[column].astype(float)
        test_df[column].astype(float)
    except ValueError:
        print(f"Column {column} still contains non-numeric values")
# Out:
# Final data types - Training:
# float64    128
# Name: count, dtype: int64
#
# Final data types - Test:
# int64      98
# float64    27
# int32       2
# int8        1
# object      1
# Name: count, dtype: int64
#
# Verifying no remaining string values:

# %%
first_selection_threshold = 0.97
second_selection_lower_threshold = 0.85
second_selection_upper_threshold = 0.98
## First selection: Features with same value in 97% or more of the data
def find_constant_features(df, threshold=0.97):
    constant_features = []
    for column in df.columns:
        # Calculate the proportion of the most frequent value
        most_frequent_prop = df[column].value_counts(normalize=True).iloc[0]
        if most_frequent_prop >= threshold:
            constant_features.append(column)
    
    return constant_features

# Second selection: Check distribution of features with same value in 85-97% of data
def analyze_near_constant_features(df, y, lower_threshold=0.85, upper_threshold=0.98):
    features_to_remove = []
    total_classes = len(np.unique(y))
    
    print(f"Total number of classes in dataset: {total_classes}")
    
    # Expected uniform distribution probability
    uniform_prob = 1.0 / total_classes
    # Allow some deviation from uniform (e.g., 2x the uniform probability)
    max_allowed_prob = uniform_prob * 2
    
    for column in df.columns:
        # Get value counts and proportions
        value_counts = df[column].value_counts(normalize=True)
        most_frequent_prop = value_counts.iloc[0]
        most_frequent_value = value_counts.index[0]
        
        # If feature has same value in 85-97% of data
        if lower_threshold <= most_frequent_prop < upper_threshold:
            # Get the minority cases (where value is different from most frequent)
            minority_mask = df[column] != most_frequent_value
            minority_labels = y[minority_mask]
            
            # Check distribution of classes in minority cases
            class_distribution = minority_labels.value_counts(normalize=True)
            
            print(f"\nAnalyzing feature: {column}")
            print(f"Most frequent value appears in {most_frequent_prop:.2%} of data")
            print("Class distribution in minority cases:")
            print(class_distribution)
            
            # Analyze distribution
            if len(class_distribution) > 1:  # Only if there are multiple classes
                max_class_prop = class_distribution.max()
                
                # Calculate entropy of distribution
                entropy = -sum(p * np.log2(p) for p in class_distribution)
                max_entropy = -np.log2(1/total_classes)  # Maximum possible entropy
                entropy_ratio = entropy / max_entropy
                
                print(f"Entropy ratio: {entropy_ratio:.2f} (1.0 would be perfectly uniform)")
                
                # Decision criteria:
                # 1. If any class is heavily overrepresented
                # 2. Or if distribution is close to uniform
                if max_class_prop < max_allowed_prob or entropy_ratio > 0.8:
                    features_to_remove.append(column)
                    print("REMOVED: Distribution is too uniform or lacks clear class separation")
                else:
                    print("KEPT: Shows significant class separation")
            else:
                print("KEPT: Only one class in minority cases (strong predictor)")
                
    return features_to_remove

# Apply the feature selection
print("Starting feature selection...")
print(f"Number of unique classes in dataset: {len(np.unique(y))}")
# Out:
# Starting feature selection...
# Number of unique classes in dataset: 128

# %%
# First stage: Remove highly constant features
constant_features = find_constant_features(X, first_selection_threshold)
print(f"\nFound {len(constant_features)} features with {first_selection_threshold}% constant values:")
for feat in constant_features:
    value_counts = X[feat].value_counts(normalize=True)
    print(f"{feat}: Most common value appears in {value_counts.iloc[0]:.2%} of cases")
# Out:
# Found 31 features with 0.97% constant values:
# Destination_port: Most common value appears in 98.91% of cases
# Protocol: Most common value appears in 100.00% of cases
# bandwidth_0: Most common value appears in 98.28% of cases
# bandwidth_4: Most common value appears in 97.34% of cases
# bandwidth_6: Most common value appears in 99.06% of cases
# bandwidth_8: Most common value appears in 99.84% of cases
# bandwidth_10: Most common value appears in 99.69% of cases
# bandwidth_12: Most common value appears in 100.00% of cases
# bandwidth_14: Most common value appears in 99.84% of cases
# bandwidth_16: Most common value appears in 100.00% of cases
# bandwidth_18: Most common value appears in 100.00% of cases
# bandwidth_19: Most common value appears in 97.03% of cases
# beaconning_1: Most common value appears in 97.97% of cases
# beaconning_2: Most common value appears in 99.06% of cases
# beaconning_3: Most common value appears in 99.53% of cases
# beaconning_4: Most common value appears in 99.69% of cases
# beaconning_5: Most common value appears in 100.00% of cases
# beaconning_6: Most common value appears in 100.00% of cases
# beaconning_7: Most common value appears in 100.00% of cases
# beaconning_8: Most common value appears in 100.00% of cases
# beaconning_9: Most common value appears in 100.00% of cases
# beaconning_10: Most common value appears in 100.00% of cases
# beaconning_11: Most common value appears in 100.00% of cases
# beaconning_12: Most common value appears in 100.00% of cases
# beaconning_13: Most common value appears in 100.00% of cases
# beaconning_14: Most common value appears in 100.00% of cases
# beaconning_15: Most common value appears in 100.00% of cases
# beaconning_16: Most common value appears in 100.00% of cases
# beaconning_17: Most common value appears in 100.00% of cases
# beaconning_18: Most common value appears in 100.00% of cases
# beaconning_19: Most common value appears in 100.00% of cases

# %%
# Remove these features
X = X.drop(columns=constant_features)
test_df = test_df.drop(columns=constant_features)

# %%
# Second stage: Analyze near-constant features
features_to_remove = analyze_near_constant_features(X, y, second_selection_lower_threshold, second_selection_upper_threshold)
print(f"\nFound {len(features_to_remove)} near-constant features to remove:")
for feat in features_to_remove:
    print(f"\n{feat}:")
    value_counts = X[feat].value_counts(normalize=True)
    print(f"Value distribution: {value_counts.head()}")
# Out:
# Total number of classes in dataset: 128
#
# Analyzing feature: min_fwd_packet
# Most frequent value appears in 93.59% of data
# Class distribution in minority cases:
# label
# doi.org               0.121951
# gizmodo               0.097561
# googleadservices      0.097561
# google                0.097561
# frax.finance          0.097561
# facebook              0.048780
# iq.wiki               0.048780
# walla                 0.048780
# bloomberg             0.048780
# YouTube               0.048780
# drip                  0.024390
# discord               0.024390
# 20thcenturystudios    0.024390
# arstechnica           0.024390
# jpost                 0.024390
# nationalgeographic    0.024390
# odysee                0.024390
# tomshardware          0.024390
# twitch                0.024390
# 1inch.io              0.024390
# Name: proportion, dtype: float64
# Entropy ratio: 0.58 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: min_bwd_packet
# Most frequent value appears in 92.97% of data
# Class distribution in minority cases:
# label
# doi.org               0.111111
# gizmodo               0.088889
# googleadservices      0.088889
# google                0.088889
# frax.finance          0.088889
# facebook              0.044444
# walla                 0.044444
# iq.wiki               0.044444
# ynet                  0.044444
# bloomberg             0.044444
# YouTube               0.044444
# forbes                0.022222
# drip                  0.022222
# 20thcenturystudios    0.022222
# discord               0.022222
# arstechnica           0.022222
# jpost                 0.022222
# nationalgeographic    0.022222
# nytimes               0.022222
# odysee                0.022222
# tomshardware          0.022222
# twitch                0.022222
# 1inch.io              0.022222
# Name: proportion, dtype: float64
# Entropy ratio: 0.61 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: min_bwd_inter_arrival_time
# Most frequent value appears in 93.91% of data
# Class distribution in minority cases:
# label
# citizendium.org         0.102564
# factmonster             0.076923
# flipboard               0.051282
# politico                0.051282
# arstechnica             0.051282
# foxbusiness             0.051282
# ssrn                    0.051282
# ycombinator             0.051282
# bbc                     0.051282
# upbit                   0.025641
# squarespace             0.025641
# x                       0.025641
# tiktok                  0.025641
# thewaltdisneycompany    0.025641
# substack                0.025641
# starwars                0.025641
# apple                   0.025641
# instagram               0.025641
# spotify                 0.025641
# outkick                 0.025641
# huffingtonpost          0.025641
# github                  0.025641
# foxnews                 0.025641
# espn                    0.025641
# disneymovieinsiders     0.025641
# disney                  0.025641
# ynet                    0.025641
# Name: proportion, dtype: float64
# Entropy ratio: 0.66 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: min_bib_inter_arrival_time
# Most frequent value appears in 96.25% of data
# Class distribution in minority cases:
# label
# citizendium.org         0.166667
# politico                0.083333
# ycombinator             0.083333
# foxbusiness             0.083333
# arstechnica             0.041667
# tiktok                  0.041667
# thewaltdisneycompany    0.041667
# starwars                0.041667
# ssrn                    0.041667
# squarespace             0.041667
# outkick                 0.041667
# bbc                     0.041667
# huffingtonpost          0.041667
# github                  0.041667
# flipboard               0.041667
# factmonster             0.041667
# espn                    0.041667
# ynet                    0.041667
# Name: proportion, dtype: float64
# Entropy ratio: 0.57 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: min_packet_size
# Most frequent value appears in 85.31% of data
# Class distribution in minority cases:
# label
# google                0.053191
# doi.org               0.053191
# facebook              0.053191
# googleadservices      0.053191
# gizmodo               0.053191
# frax.finance          0.042553
# discord               0.031915
# iq.wiki               0.031915
# tomshardware          0.031915
# economist             0.031915
# 20thcenturystudios    0.031915
# YouTube               0.031915
# techradar             0.021277
# technologyreview      0.021277
# substack              0.021277
# spotify               0.021277
# pinterest             0.021277
# jpost                 0.021277
# walla                 0.021277
# odysee                0.021277
# wired                 0.021277
# bloomberg             0.021277
# businessinsider       0.021277
# foxbusiness           0.010638
# digitaltrends         0.010638
# wikimedia.org         0.010638
# algemeiner            0.010638
# vulture               0.010638
# vox                   0.010638
# twitch                0.010638
# arstechnica           0.010638
# bbc                   0.010638
# britannica            0.010638
# cnet                  0.010638
# newyorker             0.010638
# forbes                0.010638
# ndtv                  0.010638
# nbcnews               0.010638
# nature                0.010638
# nationalgeographic    0.010638
# merriam-webster       0.010638
# disneyplus            0.010638
# disneystore           0.010638
# instagram             0.010638
# drip                  0.010638
# economistgroup        0.010638
# go                    0.010638
# 1inch.io              0.010638
# Name: proportion, dtype: float64
# Entropy ratio: 0.76 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_2
# Most frequent value appears in 87.19% of data
# Class distribution in minority cases:
# label
# scholarpedia            0.036585
# wired                   0.036585
# nbcnews                 0.036585
# newsweek                0.036585
# odysee                  0.036585
# 1inch.io                0.024390
# jpost                   0.024390
# YouTube                 0.024390
# nationalgeographic      0.024390
# newyorker               0.024390
# slate                   0.024390
# forbes                  0.024390
# teachervision           0.024390
# techradar               0.024390
# ted                     0.024390
# tomshardware            0.024390
# walla                   0.024390
# wprdc.org               0.024390
# independent             0.024390
# merriam-webster         0.024390
# x                       0.024390
# disneystore             0.024390
# buzzfeednews            0.024390
# cnbc                    0.024390
# familyeducation         0.024390
# factset                 0.024390
# cnn                     0.024390
# thewaltdisneycompany    0.012195
# tiktok                  0.012195
# binance                 0.012195
# twitter                 0.012195
# britannica              0.012195
# vk                      0.012195
# vulture                 0.012195
# bbc                     0.012195
# arstechnica             0.012195
# apple                   0.012195
# theguardian             0.012195
# foxnews                 0.012195
# buzzfeed                0.012195
# go                      0.012195
# outkick                 0.012195
# disneyplus              0.012195
# economist               0.012195
# ndtv                    0.012195
# factmonster             0.012195
# flickr                  0.012195
# instagram               0.012195
# flipboard               0.012195
# spotify                 0.012195
# Name: proportion, dtype: float64
# Entropy ratio: 0.79 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_5
# Most frequent value appears in 88.28% of data
# Class distribution in minority cases:
# label
# veoh                    0.066667
# tubitv                  0.066667
# dailymotion             0.066667
# vimeo                   0.053333
# epa.gov                 0.053333
# starwars                0.040000
# nbcnews                 0.040000
# aboutads.info           0.040000
# infoplease              0.040000
# marvel                  0.026667
# israelhayom             0.026667
# wired                   0.026667
# scholarpedia            0.026667
# ndtv                    0.026667
# merriam-webster         0.026667
# linkedin                0.026667
# x                       0.026667
# espn                    0.026667
# disneymovieinsiders     0.026667
# cnn                     0.026667
# huffpost                0.013333
# teachervision           0.013333
# adventuresbydisney      0.013333
# vk                      0.013333
# binance                 0.013333
# braindao.org            0.013333
# citizendium.org         0.013333
# thewaltdisneycompany    0.013333
# ted                     0.013333
# slate                   0.013333
# cnbc                    0.013333
# mako                    0.013333
# reddit                  0.013333
# politico                0.013333
# condenast               0.013333
# nationalgeographic      0.013333
# govt.nz                 0.013333
# 1inch.io                0.013333
# Name: proportion, dtype: float64
# Entropy ratio: 0.71 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_7
# Most frequent value appears in 92.50% of data
# Class distribution in minority cases:
# label
# veoh                    0.104167
# dailymotion             0.104167
# tubitv                  0.104167
# vimeo                   0.083333
# epa.gov                 0.083333
# nbcnews                 0.062500
# disneymovieinsiders     0.041667
# linkedin                0.041667
# aboutads.info           0.041667
# ndtv                    0.041667
# 1inch.io                0.020833
# thewaltdisneycompany    0.020833
# ted                     0.020833
# starwars                0.020833
# marvel                  0.020833
# nationalgeographic      0.020833
# merriam-webster         0.020833
# mako                    0.020833
# israelhayom             0.020833
# infoplease              0.020833
# govt.nz                 0.020833
# cnn                     0.020833
# cnbc                    0.020833
# wired                   0.020833
# Name: proportion, dtype: float64
# Entropy ratio: 0.61 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_9
# Most frequent value appears in 94.84% of data
# Class distribution in minority cases:
# label
# veoh               0.151515
# dailymotion        0.121212
# tubitv             0.121212
# vimeo              0.121212
# epa.gov            0.090909
# linkedin           0.060606
# ndtv               0.060606
# 1inch.io           0.030303
# aboutads.info      0.030303
# cnbc               0.030303
# govt.nz            0.030303
# israelhayom        0.030303
# mako               0.030303
# marvel             0.030303
# merriam-webster    0.030303
# ted                0.030303
# Name: proportion, dtype: float64
# Entropy ratio: 0.53 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_11
# Most frequent value appears in 95.47% of data
# Class distribution in minority cases:
# label
# veoh           0.172414
# tubitv         0.137931
# vimeo          0.137931
# dailymotion    0.103448
# epa.gov        0.103448
# linkedin       0.068966
# ndtv           0.068966
# 1inch.io       0.034483
# cnbc           0.034483
# govt.nz        0.034483
# israelhayom    0.034483
# mako           0.034483
# marvel         0.034483
# Name: proportion, dtype: float64
# Entropy ratio: 0.49 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_13
# Most frequent value appears in 96.25% of data
# Class distribution in minority cases:
# label
# veoh           0.208333
# tubitv         0.166667
# vimeo          0.166667
# dailymotion    0.125000
# epa.gov        0.125000
# ndtv           0.083333
# govt.nz        0.041667
# israelhayom    0.041667
# linkedin       0.041667
# Name: proportion, dtype: float64
# Entropy ratio: 0.42 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_15
# Most frequent value appears in 96.56% of data
# Class distribution in minority cases:
# label
# veoh           0.227273
# tubitv         0.181818
# vimeo          0.181818
# dailymotion    0.136364
# epa.gov        0.136364
# ndtv           0.090909
# israelhayom    0.045455
# Name: proportion, dtype: float64
# Entropy ratio: 0.38 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: bandwidth_17
# Most frequent value appears in 96.72% of data
# Class distribution in minority cases:
# label
# veoh           0.238095
# tubitv         0.190476
# vimeo          0.190476
# dailymotion    0.142857
# epa.gov        0.142857
# israelhayom    0.047619
# ndtv           0.047619
# Name: proportion, dtype: float64
# Entropy ratio: 0.37 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Analyzing feature: beaconning_0
# Most frequent value appears in 93.28% of data
# Class distribution in minority cases:
# label
# nytimes            0.116279
# aboutads.info      0.093023
# mako               0.069767
# facebook           0.046512
# teachervision      0.046512
# nbcnews            0.046512
# marvel             0.046512
# jpost              0.046512
# familyeducation    0.046512
# x                  0.046512
# bbc                0.046512
# espn               0.023256
# flickr             0.023256
# foxnews            0.023256
# apple              0.023256
# huffingtonpost     0.023256
# disneystore        0.023256
# linkedin           0.023256
# digitaltrends      0.023256
# cnn                0.023256
# citizendium.org    0.023256
# buzzfeed           0.023256
# outkick            0.023256
# twitter            0.023256
# veoh               0.023256
# google             0.023256
# Name: proportion, dtype: float64
# Entropy ratio: 0.64 (1.0 would be perfectly uniform)
# KEPT: Shows significant class separation
#
# Found 0 near-constant features to remove:

# %%
# Remove these features
X = X.drop(columns=features_to_remove)
test_df = test_df.drop(columns=features_to_remove)

print("\nFeature selection completed.")
print(f"Number of features after selection: {X.shape[1]}")
print("\nRemoved features summary:")
print(f"- {len(constant_features)} highly constant features {first_selection_threshold}")
print(f"- {len(features_to_remove)} near-constant features with uniform class distribution")
# Out:
# Feature selection completed.
# Number of features after selection: 97
#
# Removed features summary:
# - 31 highly constant features 0.97
# - 0 near-constant features with uniform class distribution

# %%
# %%
def calculate_vif(X):
    """
    Calculate VIF for each feature
    Returns DataFrame with VIF scores
    """
    vif_data = pd.DataFrame()
    X_with_constant = add_constant(X)
    vif_data["Feature"] = X_with_constant.columns
    vif_data["VIF"] = [variance_inflation_factor(X_with_constant.values, i) 
                       for i in range(X_with_constant.shape[1])]
    #print(vif_data)
    print("\nVIF scores:")
    print(vif_data)    

    # Remove the constant term's VIF
    return vif_data[vif_data['Feature'] != 'const'].sort_values('VIF', ascending=False)

# %%
def get_correlation_matrix(X):
    """
    Calculate correlation matrix and return it along with a visualization
    """
    correlation_matrix = X.corr()
    
    # Plot correlation heatmap
    # plt.figure(figsize=(12, 10))
    # sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
    # plt.title('Feature Correlation Heatmap')
    # plt.tight_layout()
    # plt.show()
    
    return correlation_matrix

def identify_correlated_features(correlation_matrix, threshold=0.95):
    """
    Find highly correlated feature pairs
    """
    highly_correlated = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i+1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) > threshold:
                highly_correlated.append((
                    correlation_matrix.columns[i],
                    correlation_matrix.columns[j],
                    correlation_matrix.iloc[i, j]
                ))
    return highly_correlated

# %%
print("Starting multicollinearity analysis...")

# Initial VIF calculation
vif_data = calculate_vif(X)
# Out:
# Starting multicollinearity analysis...
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 93  max_first_packet_size  9.762340e+00
# 94  min_first_packet_size  6.003204e+00
# 95         mean_bandwidth  1.483008e+04
# 96          std_bandwidth  3.878578e+03
# 97          max_bandwidth           inf
#
# [98 rows x 2 columns]

# %%
correlation_matrix = get_correlation_matrix(X)

# Iterative feature removal process
features_to_remove = set()
vif_threshold = 5
correlation_threshold = 0.95

while True:
    # Get features with high VIF
    high_vif_features = vif_data[vif_data['VIF'] > vif_threshold]['Feature'].tolist()
    
    if not high_vif_features:
        break
    
    # Find highly correlated pairs among high VIF features
    high_vif_correlation = identify_correlated_features(
        correlation_matrix.loc[high_vif_features, high_vif_features],
        correlation_threshold
    )
    
    if not high_vif_correlation:
        # If no high correlations, remove the feature with highest VIF
        worst_feature = vif_data.iloc[0]['Feature']
        features_to_remove.add(worst_feature)
        # print(f"\nRemoving feature with highest VIF: {worst_feature} (VIF: {vif_data.iloc[0]['VIF']:.2f})")
    else:
        # Among correlated pairs, find the one with highest VIF
        for f1, f2, corr in high_vif_correlation:
            print(f"{f1} - {f2}: correlation = {corr:.2f}")
            
        vif_dict = dict(zip(vif_data['Feature'], vif_data['VIF']))
        worst_feature = max(
            high_vif_features,
            key=lambda x: vif_dict.get(x, 0)
        )
        features_to_remove.add(worst_feature)
    
    # Remove selected feature and recalculate VIF
    X = X.drop(columns=[worst_feature])
    test_df = test_df.drop(columns=[worst_feature])
    vif_data = calculate_vif(X)
    correlation_matrix = X.corr()
# Out:
# bandwidth_1 - max_bandwidth: correlation = 1.00
# bandwidth_1 - std_bandwidth: correlation = 1.00
# total_packets - total_bytes: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# total_packets - bwd_packets_amount: correlation = 0.99
# total_packets - ACK_count: correlation = 0.98
# total_bytes - bwd_packets_length: correlation = 0.99
# total_bytes - bwd_packets_amount: correlation = 0.97
# total_bytes - ACK_count: correlation = 1.00
# total_flags - PSH_count: correlation = 1.00
# bwd_iat_mean - mean_bwd_inter_arrival_time: correlation = 1.00
# max_bandwidth - std_bandwidth: correlation = 1.00
# fwd_packets_length - fwd_packets_amount: correlation = 0.97
# bwd_packets_length - bwd_packets_amount: correlation = 0.98
# bwd_packets_length - ACK_count: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# mean_fwd_inter_arrival_time - fwd_iat_mean: correlation = 1.00
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 92  max_first_packet_size  9.762340e+00
# 93  min_first_packet_size  6.003204e+00
# 94         mean_bandwidth  1.483008e+04
# 95          std_bandwidth  3.878578e+03
# 96          max_bandwidth           inf
#
# [97 rows x 2 columns]
# max_bandwidth - bandwidth_1: correlation = 1.00
# max_bandwidth - std_bandwidth: correlation = 1.00
# bwd_iat_mean - mean_bwd_inter_arrival_time: correlation = 1.00
# total_flags - PSH_count: correlation = 1.00
# fwd_packets_amount - fwd_packets_length: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - total_bytes: correlation = 0.97
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_length - total_packets: correlation = 0.97
# bwd_packets_length - total_bytes: correlation = 0.99
# bwd_packets_length - ACK_count: correlation = 0.99
# bandwidth_1 - std_bandwidth: correlation = 1.00
# total_packets - total_bytes: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_bytes - ACK_count: correlation = 1.00
# fwd_iat_mean - mean_fwd_inter_arrival_time: correlation = 1.00
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 91  std_first_packet_size  1.201215e+01
# 92  max_first_packet_size  9.762340e+00
# 93  min_first_packet_size  6.003204e+00
# 94         mean_bandwidth  1.483008e+04
# 95          std_bandwidth  3.878578e+03
#
# [96 rows x 2 columns]
# total_bytes - bwd_packets_length: correlation = 0.99
# total_bytes - total_packets: correlation = 0.98
# total_bytes - bwd_packets_amount: correlation = 0.97
# total_bytes - ACK_count: correlation = 1.00
# bwd_packets_length - total_packets: correlation = 0.97
# bwd_packets_length - bwd_packets_amount: correlation = 0.98
# bwd_packets_length - ACK_count: correlation = 0.99
# fwd_iat_mean - mean_fwd_inter_arrival_time: correlation = 1.00
# PSH_count - total_flags: correlation = 1.00
# total_packets - bwd_packets_amount: correlation = 0.99
# total_packets - ACK_count: correlation = 0.98
# bwd_iat_mean - mean_bwd_inter_arrival_time: correlation = 1.00
# fwd_packets_length - fwd_packets_amount: correlation = 0.97
# bwd_packets_amount - ACK_count: correlation = 0.97
# bandwidth_1 - std_bandwidth: correlation = 1.00
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 90  std_first_packet_size  1.201215e+01
# 91  max_first_packet_size  9.762340e+00
# 92  min_first_packet_size  6.003204e+00
# 93         mean_bandwidth  1.483008e+04
# 94          std_bandwidth  3.878578e+03
#
# [95 rows x 2 columns]
# fwd_iat_mean - mean_fwd_inter_arrival_time: correlation = 1.00
# fwd_packets_amount - fwd_packets_length: correlation = 0.97
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# bwd_iat_mean - mean_bwd_inter_arrival_time: correlation = 1.00
# total_flags - PSH_count: correlation = 1.00
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# bandwidth_1 - std_bandwidth: correlation = 1.00
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 89  std_first_packet_size  1.201215e+01
# 90  max_first_packet_size  9.762340e+00
# 91  min_first_packet_size  6.003204e+00
# 92         mean_bandwidth  1.483008e+04
# 93          std_bandwidth  3.878578e+03
#
# [94 rows x 2 columns]
# bwd_iat_mean - mean_bwd_inter_arrival_time: correlation = 1.00
# fwd_packets_amount - fwd_packets_length: correlation = 0.97
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# PSH_count - total_flags: correlation = 1.00
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# bandwidth_1 - std_bandwidth: correlation = 1.00
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 88  std_first_packet_size  1.201215e+01
# 89  max_first_packet_size  9.762340e+00
# 90  min_first_packet_size  6.003204e+00
# 91         mean_bandwidth  1.483008e+04
# 92          std_bandwidth  3.878578e+03
#
# [93 rows x 2 columns]
# fwd_packets_amount - fwd_packets_length: correlation = 0.97
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# total_flags - PSH_count: correlation = 1.00
# bandwidth_1 - std_bandwidth: correlation = 1.00
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# C:\anconda\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 87  std_first_packet_size  1.201215e+01
# 88  max_first_packet_size  9.762340e+00
# 89  min_first_packet_size  6.003204e+00
# 90         mean_bandwidth  1.483008e+04
# 91          std_bandwidth  3.878578e+03
#
# [92 rows x 2 columns]
# PSH_count - total_flags: correlation = 1.00
# bandwidth_1 - std_bandwidth: correlation = 1.00
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.412701e+06
# 1               Source_IP  1.823288e+00
# 2             Source_port  1.163835e+00
# 3          Destination_IP  1.329742e+00
# 4               Timestamp  2.186417e+00
# ..                    ...           ...
# 86  std_first_packet_size  1.201215e+01
# 87  max_first_packet_size  9.762340e+00
# 88  min_first_packet_size  6.003204e+00
# 89         mean_bandwidth  1.483008e+04
# 90          std_bandwidth  3.878578e+03
#
# [91 rows x 2 columns]
# PSH_count - total_flags: correlation = 1.00
# bandwidth_1 - std_bandwidth: correlation = 1.00
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.403404e+06
# 1               Source_IP  1.762956e+00
# 2             Source_port  1.163191e+00
# 3          Destination_IP  1.327715e+00
# 4               Timestamp  2.171863e+00
# ..                    ...           ...
# 85  std_first_packet_size  1.201013e+01
# 86  max_first_packet_size  9.762222e+00
# 87  min_first_packet_size  6.002905e+00
# 88         mean_bandwidth  1.483005e+04
# 89          std_bandwidth  3.872723e+03
#
# [90 rows x 2 columns]
# bandwidth_1 - std_bandwidth: correlation = 1.00
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bandwidth_15 - bandwidth_17: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.402939e+06
# 1                Source_IP  1.758927e+00
# 2              Source_port  1.163073e+00
# 3           Destination_IP  1.326617e+00
# 4                Timestamp  2.171112e+00
# ..                     ...           ...
# 84  mean_first_packet_size  1.878552e+02
# 85   std_first_packet_size  1.199850e+01
# 86   max_first_packet_size  9.762087e+00
# 87   min_first_packet_size  6.002605e+00
# 88           std_bandwidth  3.493044e+03
#
# [89 rows x 2 columns]
# std_bandwidth - bandwidth_1: correlation = 1.00
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.402389e+06
# 1                Source_IP  1.752514e+00
# 2              Source_port  1.162552e+00
# 3           Destination_IP  1.310926e+00
# 4                Timestamp  2.170273e+00
# ..                     ...           ...
# 83               iat_ratio  1.044137e+01
# 84  mean_first_packet_size  1.877082e+02
# 85   std_first_packet_size  1.193648e+01
# 86   max_first_packet_size  9.723092e+00
# 87   min_first_packet_size  5.960982e+00
#
# [88 rows x 2 columns]
# bwd_packets_amount - total_packets: correlation = 0.99
# bwd_packets_amount - ACK_count: correlation = 0.97
# bwd_packets_amount - bwd_packets_length: correlation = 0.98
# total_packets - ACK_count: correlation = 0.98
# total_packets - bwd_packets_length: correlation = 0.97
# ACK_count - bwd_packets_length: correlation = 0.99
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.385390e+06
# 1                Source_IP  1.728446e+00
# 2              Source_port  1.159543e+00
# 3           Destination_IP  1.308721e+00
# 4                Timestamp  2.144717e+00
# ..                     ...           ...
# 82               iat_ratio  1.043341e+01
# 83  mean_first_packet_size  1.873469e+02
# 84   std_first_packet_size  1.171576e+01
# 85   max_first_packet_size  9.713695e+00
# 86   min_first_packet_size  5.936658e+00
#
# [87 rows x 2 columns]
# ACK_count - bwd_packets_length: correlation = 0.99
# ACK_count - total_packets: correlation = 0.98
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bwd_packets_length - total_packets: correlation = 0.97
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.384997e+06
# 1                Source_IP  1.728443e+00
# 2              Source_port  1.159540e+00
# 3           Destination_IP  1.308525e+00
# 4                Timestamp  2.144042e+00
# ..                     ...           ...
# 81               iat_ratio  1.043313e+01
# 82  mean_first_packet_size  1.873454e+02
# 83   std_first_packet_size  1.166818e+01
# 84   max_first_packet_size  9.651582e+00
# 85   min_first_packet_size  5.898843e+00
#
# [86 rows x 2 columns]
# bandwidth_9 - bandwidth_11: correlation = 1.00
# bandwidth_9 - bandwidth_7: correlation = 1.00
# bandwidth_11 - bandwidth_7: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bwd_packets_length - total_packets: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.382266e+06
# 1                Source_IP  1.724865e+00
# 2              Source_port  1.159342e+00
# 3           Destination_IP  1.307205e+00
# 4                Timestamp  2.139756e+00
# ..                     ...           ...
# 80               iat_ratio  1.043313e+01
# 81  mean_first_packet_size  1.873421e+02
# 82   std_first_packet_size  1.157996e+01
# 83   max_first_packet_size  9.650995e+00
# 84   min_first_packet_size  5.886036e+00
#
# [85 rows x 2 columns]
# bandwidth_7 - bandwidth_11: correlation = 1.00
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bwd_packets_length - total_packets: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                    Feature           VIF
# 0                    const  1.375462e+06
# 1                Source_IP  1.724843e+00
# 2              Source_port  1.157993e+00
# 3           Destination_IP  1.304830e+00
# 4                Timestamp  2.129197e+00
# ..                     ...           ...
# 79               iat_ratio  1.043160e+01
# 80  mean_first_packet_size  1.873270e+02
# 81   std_first_packet_size  1.154322e+01
# 82   max_first_packet_size  9.642272e+00
# 83   min_first_packet_size  5.843054e+00
#
# [84 rows x 2 columns]
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bwd_packets_length - total_packets: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.374642e+06
# 1               Source_IP  1.722913e+00
# 2             Source_port  1.156416e+00
# 3          Destination_IP  1.304785e+00
# 4               Timestamp  2.127937e+00
# ..                    ...           ...
# 78            total_flags  9.145627e+00
# 79              iat_ratio  1.043072e+01
# 80  std_first_packet_size  1.145116e+01
# 81  max_first_packet_size  9.638601e+00
# 82  min_first_packet_size  5.836177e+00
#
# [83 rows x 2 columns]
# max_bib_inter_arrival_time - max_fwd_inter_arrival_time: correlation = 0.99
# bwd_packets_length - total_packets: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.374355e+06
# 1               Source_IP  1.718546e+00
# 2             Source_port  1.152641e+00
# 3          Destination_IP  1.304163e+00
# 4               Timestamp  2.127397e+00
# ..                    ...           ...
# 77            total_flags  9.140186e+00
# 78              iat_ratio  8.176023e+00
# 79  std_first_packet_size  1.144432e+01
# 80  max_first_packet_size  9.627395e+00
# 81  min_first_packet_size  5.832639e+00
#
# [82 rows x 2 columns]
# bwd_packets_length - total_packets: correlation = 0.97
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.362722e+06
# 1               Source_IP  1.639431e+00
# 2             Source_port  1.152473e+00
# 3          Destination_IP  1.294693e+00
# 4               Timestamp  2.108887e+00
# ..                    ...           ...
# 76            total_flags  9.117706e+00
# 77              iat_ratio  8.135104e+00
# 78  std_first_packet_size  1.134299e+01
# 79  max_first_packet_size  9.625695e+00
# 80  min_first_packet_size  5.823409e+00
#
# [81 rows x 2 columns]
# bpp_1 - bpp_2: correlation = 0.97
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.358423e+06
# 1               Source_IP  1.636281e+00
# 2             Source_port  1.152468e+00
# 3          Destination_IP  1.294413e+00
# 4               Timestamp  2.102162e+00
# ..                    ...           ...
# 75            total_flags  9.106813e+00
# 76              iat_ratio  8.133397e+00
# 77  std_first_packet_size  1.133986e+01
# 78  max_first_packet_size  9.580764e+00
# 79  min_first_packet_size  5.821785e+00
#
# [80 rows x 2 columns]
# bandwidth_15 - bandwidth_17: correlation = 0.97
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.358210e+06
# 1               Source_IP  1.636123e+00
# 2             Source_port  1.152303e+00
# 3          Destination_IP  1.293915e+00
# 4               Timestamp  2.101840e+00
# ..                    ...           ...
# 74            total_flags  7.863615e+00
# 75              iat_ratio  8.129124e+00
# 76  std_first_packet_size  1.132528e+01
# 77  max_first_packet_size  9.560041e+00
# 78  min_first_packet_size  5.814134e+00
#
# [79 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.353569e+06
# 1               Source_IP  1.636123e+00
# 2             Source_port  1.149615e+00
# 3          Destination_IP  1.290895e+00
# 4               Timestamp  2.094438e+00
# ..                    ...           ...
# 73            total_flags  7.860908e+00
# 74              iat_ratio  8.119036e+00
# 75  std_first_packet_size  1.127304e+01
# 76  max_first_packet_size  9.536893e+00
# 77  min_first_packet_size  5.814111e+00
#
# [78 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.352205e+06
# 1               Source_IP  1.634562e+00
# 2             Source_port  1.145834e+00
# 3          Destination_IP  1.290612e+00
# 4               Timestamp  2.092478e+00
# ..                    ...           ...
# 72            total_flags  7.860787e+00
# 73              iat_ratio  4.447925e+00
# 74  std_first_packet_size  1.127045e+01
# 75  max_first_packet_size  9.504535e+00
# 76  min_first_packet_size  5.813427e+00
#
# [77 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.350885e+06
# 1               Source_IP  1.622007e+00
# 2             Source_port  1.144364e+00
# 3          Destination_IP  1.290392e+00
# 4               Timestamp  2.090167e+00
# ..                    ...           ...
# 71            total_flags  7.843085e+00
# 72              iat_ratio  4.442469e+00
# 73  std_first_packet_size  1.116099e+01
# 74  max_first_packet_size  9.496243e+00
# 75  min_first_packet_size  5.811423e+00
#
# [76 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.303926e+06
# 1               Source_IP  1.621860e+00
# 2             Source_port  1.143804e+00
# 3          Destination_IP  1.287030e+00
# 4               Timestamp  2.017563e+00
# ..                    ...           ...
# 70            total_flags  7.842955e+00
# 71              iat_ratio  4.433824e+00
# 72  std_first_packet_size  1.109659e+01
# 73  max_first_packet_size  9.460795e+00
# 74  min_first_packet_size  5.651499e+00
#
# [75 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.299814e+06
# 1               Source_IP  1.609930e+00
# 2             Source_port  1.143049e+00
# 3          Destination_IP  1.286809e+00
# 4               Timestamp  2.011144e+00
# ..                    ...           ...
# 69            total_flags  7.783498e+00
# 70              iat_ratio  4.433821e+00
# 71  std_first_packet_size  1.083880e+01
# 72  max_first_packet_size  9.451672e+00
# 73  min_first_packet_size  5.633275e+00
#
# [74 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.285745e+06
# 1               Source_IP  1.607377e+00
# 2             Source_port  1.140702e+00
# 3          Destination_IP  1.286672e+00
# 4               Timestamp  1.989549e+00
# ..                    ...           ...
# 68            total_flags  7.750162e+00
# 69              iat_ratio  4.356433e+00
# 70  std_first_packet_size  1.082079e+01
# 71  max_first_packet_size  9.402561e+00
# 72  min_first_packet_size  5.630561e+00
#
# [73 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.285658e+06
# 1               Source_IP  1.605999e+00
# 2             Source_port  1.140424e+00
# 3          Destination_IP  1.279313e+00
# 4               Timestamp  1.989352e+00
# ..                    ...           ...
# 67            total_flags  7.749927e+00
# 68              iat_ratio  4.349490e+00
# 69  std_first_packet_size  1.082051e+01
# 70  max_first_packet_size  9.402362e+00
# 71  min_first_packet_size  5.601798e+00
#
# [72 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.281754e+06
# 1               Source_IP  1.605567e+00
# 2             Source_port  1.140146e+00
# 3          Destination_IP  1.274585e+00
# 4               Timestamp  1.983316e+00
# ..                    ...           ...
# 66            total_flags  7.748226e+00
# 67              iat_ratio  4.345086e+00
# 68  std_first_packet_size  1.077270e+01
# 69  max_first_packet_size  9.373045e+00
# 70  min_first_packet_size  5.600056e+00
#
# [71 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.270898e+06
# 1               Source_IP  1.605547e+00
# 2             Source_port  1.122340e+00
# 3          Destination_IP  1.273712e+00
# 4               Timestamp  1.966066e+00
# ..                    ...           ...
# 65    avg_bwd_packet_size  4.894943e+00
# 66            total_flags  7.748225e+00
# 67              iat_ratio  4.341980e+00
# 68  max_first_packet_size  8.457659e+00
# 69  min_first_packet_size  4.929411e+00
#
# [70 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.270842e+06
# 1               Source_IP  1.603497e+00
# 2             Source_port  1.111059e+00
# 3          Destination_IP  1.266296e+00
# 4               Timestamp  1.966031e+00
# ..                    ...           ...
# 64    avg_bwd_packet_size  4.889904e+00
# 65            total_flags  7.746121e+00
# 66              iat_ratio  1.496124e+00
# 67  max_first_packet_size  8.455922e+00
# 68  min_first_packet_size  4.924151e+00
#
# [69 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.173341e+06
# 1               Source_IP  1.597138e+00
# 2             Source_port  1.108268e+00
# 3          Destination_IP  1.257658e+00
# 4               Timestamp  1.814261e+00
# ..                    ...           ...
# 63    avg_bwd_packet_size  4.878159e+00
# 64            total_flags  7.743451e+00
# 65              iat_ratio  1.495599e+00
# 66  max_first_packet_size  6.282287e+00
# 67  min_first_packet_size  4.308494e+00
#
# [68 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.173114e+06
# 1               Source_IP  1.592725e+00
# 2             Source_port  1.103889e+00
# 3          Destination_IP  1.255372e+00
# 4               Timestamp  1.813884e+00
# ..                    ...           ...
# 62    avg_bwd_packet_size  4.875390e+00
# 63            total_flags  2.644316e+00
# 64              iat_ratio  1.494792e+00
# 65  max_first_packet_size  6.261831e+00
# 66  min_first_packet_size  4.307930e+00
#
# [67 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.161292e+06
# 1               Source_IP  1.591546e+00
# 2             Source_port  1.102718e+00
# 3          Destination_IP  1.235784e+00
# 4               Timestamp  1.795170e+00
# ..                    ...           ...
# 61    avg_bwd_packet_size  4.862099e+00
# 62            total_flags  2.640352e+00
# 63              iat_ratio  1.493989e+00
# 64  max_first_packet_size  4.591941e+00
# 65  min_first_packet_size  4.270352e+00
#
# [66 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.160572e+06
# 1               Source_IP  1.554747e+00
# 2             Source_port  1.102715e+00
# 3          Destination_IP  1.217152e+00
# 4               Timestamp  1.793946e+00
# ..                    ...           ...
# 60    avg_bwd_packet_size  4.771052e+00
# 61            total_flags  1.771553e+00
# 62              iat_ratio  1.493564e+00
# 63  max_first_packet_size  4.591590e+00
# 64  min_first_packet_size  4.254043e+00
#
# [65 rows x 2 columns]
#
# VIF scores:
#                   Feature           VIF
# 0                   const  1.137661e+06
# 1               Source_IP  1.546955e+00
# 2             Source_port  1.099979e+00
# 3          Destination_IP  1.217013e+00
# 4               Timestamp  1.759315e+00
# ..                    ...           ...
# 59    avg_bwd_packet_size  4.722697e+00
# 60            total_flags  1.709675e+00
# 61              iat_ratio  1.490373e+00
# 62  max_first_packet_size  4.031951e+00
# 63  min_first_packet_size  3.648377e+00
#
# [64 rows x 2 columns]

# %%
print("\nMulticollinearity analysis completed.")
print(f"Removed {len(features_to_remove)} features due to high multicollinearity:")
# Out:
# Multicollinearity analysis completed.
# Removed 34 features due to high multicollinearity:

# %%
def perform_chi_square_test(X, y, significance_level=0.05):
    """
    Perform chi-square test on categorical features
    """
    # Find categorical columns (those that were label encoded)
    results = []
    
    print("Performing Chi-square test on categorical features...")
    for column in X.columns:
        # Create contingency table
        contingency_table = pd.crosstab(X[column], y)
        
        # Perform chi-square test
        chi2, p_value, dof, expected = chi2_contingency(contingency_table)
        
        # Store results
        results.append({
            'Feature': column,
            'Chi-Square': chi2,
            'P-value': p_value,
            'Degrees of Freedom': dof
        })
    
    # Convert to DataFrame and sort by chi-square value
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('Chi-Square', ascending=False)
    
    # Identify significant features
    significant_features = results_df[results_df['P-value'] < significance_level]
    
    # Print results
    print("\nChi-square test results:")
    print(results_df)
    print(f"\nFound {len(significant_features)} significant features at {significance_level} significance level")
    print("\nSignificant features:")
    print(significant_features['Feature'].tolist())
    
    return results_df

# Perform chi-square test
chi_square_results = perform_chi_square_test(X, y)
# Out:
# Performing Chi-square test on categorical features...
#
# Chi-square test results:
#                        Feature    Chi-Square       P-value  Degrees of Freedom
# 3                    Timestamp  81280.000000  3.757255e-01               81153
# 52                     pps_fwd  81152.000000  3.765733e-01               81026
# 53                     pps_bwd  80725.333333  3.022705e-01               80518
# 1                  Source_port  79616.000000  5.909008e-02               78994
# 44            mean_packet_size  79452.444444  1.737608e-02               78613
# ..                         ...           ...           ...                 ...
# 6               min_fwd_packet   2116.431727  2.607194e-45                1270
# 8               min_bwd_packet   1903.058824  3.176294e-18                1397
# 9                    SYN_count   1591.952628  1.520966e-09                1270
# 13  min_bwd_inter_arrival_time   1445.590682  1.784227e-01                1397
# 10                   RST_count    542.539711  9.591062e-08                 381
#
# [63 rows x 4 columns]
#
# Found 56 significant features at 0.05 significance level
#
# Significant features:
# ['mean_packet_size', 'mean_delta_byte', 'max_fwd_inter_arrival_time', 'Destination_IP', 'packets_ratio', 'avg_fwd_packet_size', 'avg_bwd_packet_size', 'max_bwd_inter_arrival_time', 'mean_bwd_inter_arrival_time', 'bytes_ratio', 'first_packet_sizes_4', 'first_packet_sizes_12', 'fwd_packets_length', 'first_packet_sizes_9', 'first_packet_sizes_11', 'first_packet_sizes_14', 'first_packet_sizes_13', 'first_packet_sizes_10', 'first_packet_sizes_8', 'total_flags', 'first_packet_sizes_15', 'first_packet_sizes_7', 'first_packet_sizes_16', 'min_fwd_inter_arrival_time', 'first_packet_sizes_17', 'bandwidth_3', 'first_packet_sizes_18', 'max_first_packet_size', 'first_packet_sizes_20', 'first_packet_sizes_19', 'first_packet_sizes_21', 'first_packet_sizes_6', 'max_fwd_packet ', 'bandwidth_1', 'first_packet_sizes_24', 'first_packet_sizes_23', 'first_packet_sizes_26', 'first_packet_sizes_27', 'first_packet_sizes_25', 'first_packet_sizes_28', 'first_packet_sizes_29', 'min_first_packet_size', 'first_packet_sizes_5', 'bandwidth_2', 'count_big_requests', 'max_bwd_packet', 'beaconning_0', 'first_packet_sizes_2', 'Source_IP', 'first_packet_sizes_0', 'bandwidth_13', 'bandwidth_17', 'min_fwd_packet', 'min_bwd_packet', 'SYN_count', 'RST_count']

# %%
print("Remaining features after chi-square test:")
print(X.columns.tolist())
# Out:
# Remaining features after chi-square test:
# ['Source_IP', 'Source_port', 'Destination_IP', 'Timestamp', 'fwd_packets_length', 'max_fwd_packet ', 'min_fwd_packet', 'max_bwd_packet', 'min_bwd_packet', 'SYN_count', 'RST_count', 'min_fwd_inter_arrival_time', 'max_fwd_inter_arrival_time', 'min_bwd_inter_arrival_time', 'max_bwd_inter_arrival_time', 'mean_bwd_inter_arrival_time', 'min_bib_inter_arrival_time', 'first_packet_sizes_0', 'first_packet_sizes_2', 'first_packet_sizes_4', 'first_packet_sizes_5', 'first_packet_sizes_6', 'first_packet_sizes_7', 'first_packet_sizes_8', 'first_packet_sizes_9', 'first_packet_sizes_10', 'first_packet_sizes_11', 'first_packet_sizes_12', 'first_packet_sizes_13', 'first_packet_sizes_14', 'first_packet_sizes_15', 'first_packet_sizes_16', 'first_packet_sizes_17', 'first_packet_sizes_18', 'first_packet_sizes_19', 'first_packet_sizes_20', 'first_packet_sizes_21', 'first_packet_sizes_23', 'first_packet_sizes_24', 'first_packet_sizes_25', 'first_packet_sizes_26', 'first_packet_sizes_27', 'first_packet_sizes_28', 'first_packet_sizes_29', 'mean_packet_size', 'mean_delta_byte', 'bandwidth_1', 'bandwidth_2', 'bandwidth_3', 'bandwidth_13', 'bandwidth_17', 'beaconning_0', 'pps_fwd', 'pps_bwd', 'count_big_requests', 'packets_ratio', 'bytes_ratio', 'avg_fwd_packet_size', 'avg_bwd_packet_size', 'total_flags', 'iat_ratio', 'max_first_packet_size', 'min_first_packet_size']

# %%
# %%
def perform_anova_feature_selection(X, y, significance_level=0.05):
    """
    Perform ANOVA F-test for numeric features
    """
    results = []
    print("Performing ANOVA F-test on numeric features...")
    
    for column in X.columns:
        # Create lists of values for each class
        class_values = [X[column][y == class_label] for class_label in np.unique(y)]
        
        # Perform one-way ANOVA
        f_statistic, p_value = stats.f_oneway(*class_values)
        
        # Calculate effect size (eta-squared)
        # Between-group sum of squares
        grand_mean = np.mean([values.mean() for values in class_values])
        ss_between = sum(len(values) * (values.mean() - grand_mean)**2 for values in class_values)
        
        # Total sum of squares
        all_values = np.concatenate(class_values)
        ss_total = sum((all_values - grand_mean)**2)
        
        # Calculate eta-squared
        eta_squared = ss_between / ss_total if ss_total != 0 else 0
        
        results.append({
            'Feature': column,
            'F-statistic': f_statistic,
            'P-value': p_value,
            'Effect Size (eta²)': eta_squared
        })
    
    # Convert to DataFrame and sort by F-statistic
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('F-statistic', ascending=False)
    
    # Identify significant features with meaningful effect size
    # Using both statistical significance and effect size thresholds
    significant_features = results_df[
        (results_df['P-value'] < significance_level) & 
        (results_df['Effect Size (eta²)'] > 0.01)  # Small effect size threshold
    ]
    
    print("\nANOVA F-test results:")
    print(results_df)
    print(f"\nFound {len(significant_features)} significant features with meaningful effect size")
    print("\nSignificant features with meaningful effect size:")
    print(significant_features['Feature'].tolist())
    
    # Create lists of features to keep and remove
    features_to_keep = significant_features['Feature'].tolist()
    features_to_remove = [col for col in X.columns if col not in features_to_keep]
    
    # Remove non-significant features or those with negligible effect size
    X_selected = X[features_to_keep]
    test_df_selected = test_df[features_to_keep]
    
    print(f"\nRemoved {len(features_to_remove)} features")
    print(f"Remaining features: {X_selected.shape[1]}")
    
    return X_selected, test_df_selected, results_df

# Perform ANOVA feature selection
X_selected, test_df_selected, anova_results = perform_anova_feature_selection(X, y)
# Out:
# Performing ANOVA F-test on numeric features...
#
# ANOVA F-test results:
#                        Feature  F-statistic        P-value  Effect Size (eta²)
# 3                    Timestamp    34.682108  5.916456e-188            0.895864
# 0                    Source_IP    25.539881  5.409471e-159            0.863669
# 59                 total_flags    10.320217   1.453931e-83            0.719093
# 5              max_fwd_packet     10.319443   1.472234e-83            0.719078
# 2               Destination_IP     6.922803   5.171337e-57            0.631971
# ..                         ...          ...            ...                 ...
# 60                   iat_ratio     1.151232   1.478133e-01            0.222129
# 8               min_bwd_packet     1.015088   4.462861e-01            0.201144
# 47                 bandwidth_2     1.007586   4.672973e-01            0.199954
# 52                     pps_fwd     0.995090   5.027458e-01            0.197965
# 16  min_bib_inter_arrival_time     0.952562   6.241736e-01            0.191122
#
# [63 rows x 4 columns]
#
# Found 58 significant features with meaningful effect size
#
# Significant features with meaningful effect size:
# ['Timestamp', 'Source_IP', 'total_flags', 'max_fwd_packet ', 'Destination_IP', 'first_packet_sizes_5', 'first_packet_sizes_4', 'max_first_packet_size', 'bandwidth_1', 'fwd_packets_length', 'first_packet_sizes_0', 'Source_port', 'first_packet_sizes_2', 'first_packet_sizes_6', 'mean_packet_size', 'max_bwd_inter_arrival_time', 'first_packet_sizes_8', 'bytes_ratio', 'count_big_requests', 'first_packet_sizes_7', 'mean_delta_byte', 'first_packet_sizes_9', 'first_packet_sizes_21', 'max_fwd_inter_arrival_time', 'first_packet_sizes_19', 'mean_bwd_inter_arrival_time', 'first_packet_sizes_20', 'RST_count', 'first_packet_sizes_10', 'avg_bwd_packet_size', 'first_packet_sizes_15', 'first_packet_sizes_12', 'first_packet_sizes_17', 'min_first_packet_size', 'first_packet_sizes_24', 'first_packet_sizes_23', 'first_packet_sizes_11', 'first_packet_sizes_18', 'first_packet_sizes_14', 'bandwidth_3', 'avg_fwd_packet_size', 'beaconning_0', 'bandwidth_17', 'first_packet_sizes_28', 'first_packet_sizes_25', 'max_bwd_packet', 'first_packet_sizes_29', 'packets_ratio', 'first_packet_sizes_26', 'first_packet_sizes_27', 'SYN_count', 'min_fwd_packet', 'min_bwd_inter_arrival_time', 'first_packet_sizes_13', 'pps_bwd', 'bandwidth_13', 'first_packet_sizes_16', 'min_fwd_inter_arrival_time']
#
# Removed 5 features
# Remaining features: 58

# %%
print("Remaining features after ANOVA F-test:")
print(X.columns.tolist())
# Out:
# Remaining features after ANOVA F-test:
# ['Source_IP', 'Source_port', 'Destination_IP', 'Timestamp', 'fwd_packets_length', 'max_fwd_packet ', 'min_fwd_packet', 'max_bwd_packet', 'min_bwd_packet', 'SYN_count', 'RST_count', 'min_fwd_inter_arrival_time', 'max_fwd_inter_arrival_time', 'min_bwd_inter_arrival_time', 'max_bwd_inter_arrival_time', 'mean_bwd_inter_arrival_time', 'min_bib_inter_arrival_time', 'first_packet_sizes_0', 'first_packet_sizes_2', 'first_packet_sizes_4', 'first_packet_sizes_5', 'first_packet_sizes_6', 'first_packet_sizes_7', 'first_packet_sizes_8', 'first_packet_sizes_9', 'first_packet_sizes_10', 'first_packet_sizes_11', 'first_packet_sizes_12', 'first_packet_sizes_13', 'first_packet_sizes_14', 'first_packet_sizes_15', 'first_packet_sizes_16', 'first_packet_sizes_17', 'first_packet_sizes_18', 'first_packet_sizes_19', 'first_packet_sizes_20', 'first_packet_sizes_21', 'first_packet_sizes_23', 'first_packet_sizes_24', 'first_packet_sizes_25', 'first_packet_sizes_26', 'first_packet_sizes_27', 'first_packet_sizes_28', 'first_packet_sizes_29', 'mean_packet_size', 'mean_delta_byte', 'bandwidth_1', 'bandwidth_2', 'bandwidth_3', 'bandwidth_13', 'bandwidth_17', 'beaconning_0', 'pps_fwd', 'pps_bwd', 'count_big_requests', 'packets_ratio', 'bytes_ratio', 'avg_fwd_packet_size', 'avg_bwd_packet_size', 'total_flags', 'iat_ratio', 'max_first_packet_size', 'min_first_packet_size']

# %%
y_test = test_df['label']

# Remove 'label' column from test data
if 'label' in test_df.columns:
    X_test = test_df.drop(columns=['label'])

# Verify column alignment
missing_cols = set(X.columns) - set(X_test.columns)
extra_cols = set(X_test.columns) - set(X.columns)

if missing_cols:
    print(f"\nWarning: Test data is missing columns: {missing_cols}")
if extra_cols:
    print(f"\nWarning: Test data has extra columns: {extra_cols}")

# Ensure columns are in the same order as training data
X_test = test_df[X.columns]

# %%
# X_test

# %%
from sklearn.metrics import accuracy_score

print("\nTraining Random Forest model...")
rf_model = RandomForestClassifier(
    n_estimators=100,  # Number of trees
    random_state=42,   # For reproducibility
    n_jobs=-1          # Use all available cores
)

# rf_model.fit(X_train, y_train)
rf_model.fit(X, y)

# Predict on test data
y_pred = rf_model.predict(X_test)

 # Evaluate model
print("\nRandom Forest - Test Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Accuracy
print("\nRandom Forest - Test Classification Report:")
print(classification_report(y_test, y_pred))

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Training Random Forest model...
#
# Random Forest - Test Confusion Matrix:
# [[2 0 0 ... 0 0 0]
#  [0 3 0 ... 0 0 0]
#  [0 0 3 ... 0 0 0]
#  ...
#  [0 0 0 ... 4 0 0]
#  [0 0 0 ... 0 3 0]
#  [0 0 0 ... 0 0 4]]
#
# Random Forest - Test Classification Report:
#                        precision    recall  f1-score   support
#
#              1inch.io       0.50      0.40      0.44         5
#    20thcenturystudios       1.00      0.60      0.75         5
#               YouTube       1.00      0.60      0.75         5
#         aboutads.info       0.67      0.80      0.73         5
#    adventuresbydisney       0.80      0.80      0.80         5
# alainelkanninterviews       1.00      1.00      1.00         5
#            algemeiner       0.75      0.60      0.67         5
#             amazonaws       0.71      1.00      0.83         5
#                 apple       0.60      0.60      0.60         5
#           arstechnica       0.36      0.80      0.50         5
#        atlantis-press       1.00      0.80      0.89         5
#                 axios       0.33      0.60      0.43         5
#                   bbc       0.60      0.60      0.60         5
#               binance       0.75      0.60      0.67         5
#             bloomberg       0.00      0.00      0.00         5
#  bondprotocol.finance       0.83      1.00      0.91         5
#          braindao.org       0.57      0.80      0.67         5
#             brainfund       0.83      1.00      0.91         5
#            britannica       1.00      0.60      0.75         5
#       businessinsider       0.50      0.20      0.29         5
#              buzzfeed       0.00      0.00      0.00         5
#          buzzfeednews       0.50      0.80      0.62         5
#                ca.gov       1.00      0.20      0.33         5
#               cern.ch       0.83      1.00      0.91         5
#       citizendium.org       0.33      0.20      0.25         5
#                  cnbc       0.83      1.00      0.91         5
#                  cnet       0.50      0.40      0.44         5
#                   cnn       0.33      0.40      0.36         5
#             condenast       0.62      1.00      0.77         5
#   creativecommons.org       1.00      0.60      0.75         5
#           dailymotion       0.83      1.00      0.91         5
#         digitaltrends       0.40      0.40      0.40         5
#               discord       0.20      0.20      0.20         5
#                disney       0.50      0.80      0.62         5
#   disneymovieinsiders       0.44      0.80      0.57         5
#            disneyplus       0.60      0.60      0.60         5
#           disneystore       0.00      0.00      0.00         5
#               doi.org       0.71      1.00      0.83         5
#                  drip       0.60      0.60      0.60         5
#                  dtmg       1.00      1.00      1.00         5
#             economist       0.00      0.00      0.00         5
#        economistgroup       0.60      0.60      0.60         5
#               eia.gov       0.71      1.00      0.83         5
#       encyclopediaapi       1.00      1.00      1.00         5
#               epa.gov       1.00      0.40      0.57         5
#                  espn       0.00      0.00      0.00         5
#              facebook       0.00      0.00      0.00         5
#           factmonster       0.50      0.80      0.62         5
#               factset       1.00      0.80      0.89         5
#       familyeducation       0.40      0.40      0.40         5
#           fastcompany       0.67      0.80      0.73         5
#                flickr       0.56      1.00      0.71         5
#             flipboard       0.50      0.60      0.55         5
#                forbes       0.50      0.40      0.44         5
#           foxbusiness       1.00      0.40      0.57         5
#               foxnews       1.00      0.40      0.57         5
#            foxweather       0.50      0.60      0.55         5
#          frax.finance       0.67      0.40      0.50         5
#                github       0.33      0.20      0.25         5
#               gizmodo       1.00      0.60      0.75         5
#                    go       0.00      0.00      0.00         5
#                google       0.45      1.00      0.62         5
#      googleadservices       1.00      0.80      0.89         5
#               govt.nz       0.83      1.00      0.91         5
#        huffingtonpost       0.50      0.20      0.29         5
#              huffpost       0.50      1.00      0.67         5
#           independent       0.45      1.00      0.62         5
#            infoplease       0.67      0.40      0.50         5
#             instagram       0.38      0.60      0.46         5
#               iq.wiki       0.38      0.60      0.46         5
#           israelhayom       1.00      0.80      0.89         5
#                 jpost       0.56      1.00      0.71         5
#              linkedin       1.00      0.20      0.33         5
#                  mako       0.50      0.40      0.44         5
#                marvel       0.71      1.00      0.83         5
#       merriam-webster       0.75      0.60      0.67         5
#        moviesanywhere       0.60      0.60      0.60         5
#    nationalgeographic       0.80      0.80      0.80         5
#                nature       0.40      0.40      0.40         5
#               nbcnews       0.80      0.80      0.80         5
#                  ndtv       0.62      1.00      0.77         5
#              newsweek       0.33      0.40      0.36         5
#             newyorker       0.50      0.40      0.44         5
#                   npr       0.75      0.60      0.67         5
#               nytimes       1.00      0.80      0.89         5
#                odysee       1.00      1.00      1.00         5
#               outkick       0.17      0.20      0.18         5
#                 pcmag       0.57      0.80      0.67         5
#             pinterest       1.00      0.20      0.33         5
#              politico       0.67      0.40      0.50         5
#                reddit       0.00      0.00      0.00         5
#             resources       0.38      1.00      0.56         5
#               revolut       0.80      0.80      0.80         5
#          scholarpedia       0.83      1.00      0.91         5
#                 slate       0.50      0.20      0.29         5
#               spotify       0.50      0.40      0.44         5
#           squarespace       0.38      0.60      0.46         5
#                  ssrn       0.71      1.00      0.83         5
#              starwars       0.62      1.00      0.77         5
#              substack       0.67      0.80      0.73         5
#                  t.me       0.75      0.60      0.67         5
#         teachervision       0.80      0.80      0.80         5
#      technologyreview       0.71      1.00      0.83         5
#             techradar       0.20      0.20      0.20         5
#                   ted       0.71      1.00      0.83         5
#           theguardian       0.67      0.40      0.50         5
#  thewaltdisneycompany       0.75      0.60      0.67         5
#                tiktok       1.00      0.80      0.89         5
#          tomshardware       0.33      0.60      0.43         5
#                tubitv       1.00      0.80      0.89         5
#                twitch       1.00      0.20      0.33         5
#               twitter       0.00      0.00      0.00         5
#                 upbit       1.00      0.40      0.57         5
#              usda.gov       1.00      1.00      1.00         5
#                  veoh       1.00      1.00      1.00         5
#                 vimeo       1.00      1.00      1.00         5
#                    vk       1.00      1.00      1.00         5
#                   vox       0.00      0.00      0.00         5
#               vulture       0.50      0.40      0.44         5
#                 walla       0.75      0.60      0.67         5
#         wikimedia.org       0.00      0.00      0.00         5
#         wikipedia.org       0.57      0.80      0.67         5
#                 wired       0.75      0.60      0.67         5
#             wprdc.org       1.00      1.00      1.00         5
#                     x       0.50      0.40      0.44         5
#           ycombinator       1.00      0.80      0.89         5
#                  ynet       0.60      0.60      0.60         5
#         youradchoices       0.80      0.80      0.80         5
#
#              accuracy                           0.62       640
#             macro avg       0.63      0.62      0.59       640
#          weighted avg       0.63      0.62      0.59       640
#
# Accuracy: 0.6172
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Feature importance plot
print("\nGenerating feature importance plot...")
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values('importance', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='importance', y='feature', data=feature_importance.head(20))
plt.title('Top 20 Most Important Features')
plt.xlabel('Feature Importance')
plt.tight_layout()
plt.show()
# Out:
# Generating feature importance plot...

# %%
number_of_top_features = 7
top_features = feature_importance.head(number_of_top_features)['feature'].tolist()
print(f"Selected top {number_of_top_features} features:")
for i, feat in enumerate(top_features, 1):
    importance = feature_importance[feature_importance['feature'] == feat]['importance'].iloc[0]
    print(f"{i}. {feat} (importance: {importance:.4f})")
# Out:
# Selected top 7 features:
# 1. Timestamp (importance: 0.0695)
# 2. Destination_IP (importance: 0.0519)
# 3. Source_port (importance: 0.0367)
# 4. packets_ratio (importance: 0.0257)
# 5. mean_delta_byte (importance: 0.0240)
# 6. max_fwd_inter_arrival_time (importance: 0.0234)
# 7. mean_packet_size (importance: 0.0233)

# %%
# Create new datasets with only top features
X_top = X[top_features]
test_df_top = X_test[top_features]

# %%
X_top
# Out:
#         Timestamp  Destination_IP  Source_port  packets_ratio  \
# 0    1.728158e+09           306.0      52264.0       0.352798
# 1    1.728158e+09           306.0      52286.0       0.353060
# 2    1.727977e+09           177.0      55125.0       0.835225
# 3    1.728158e+09           306.0      52287.0       0.353323
# 4    1.728158e+09           377.0      51187.0       0.500000
# ..            ...             ...          ...            ...
# 635  1.728162e+09           345.0      56423.0       0.627119
# 636  1.728161e+09           345.0      55393.0       0.672956
# 637  1.728161e+09           345.0      55394.0       0.904762
# 638  1.728161e+09           345.0      55447.0       0.413302
# 639  1.728161e+09           345.0      55908.0       0.863636
#
#      mean_delta_byte  max_fwd_inter_arrival_time  mean_packet_size
# 0         336.781195                   15.164509       1037.280193
# 1         342.527473                   15.164509       1134.339416
# 2         250.699507                    6.609804        652.225490
# 3         433.982759                   15.164509       1046.841202
# 4         334.228571                    0.548142        680.000000
# ..               ...                         ...               ...
# 635       287.583062                    0.133076        783.902597
# 636       297.571930                    0.670242        756.055944
# 637       350.666667                    0.134311        418.526316
# 638       286.526829                    1.918182        921.668831
# 639       363.294118                    0.139170        442.000000
#
# [640 rows x 7 columns]

# %%
# Check class distribution
class_counts = pd.Series(y).value_counts()

print("\nClass distribution in training set:")
print(class_counts)
min_samples = class_counts.min()
print(f"\nSmallest class has {min_samples} samples")

# Determine appropriate number of folds
n_splits = min(3, min_samples)  # Use minimum between 3 and smallest class size
print(f"Using {n_splits}-fold cross-validation")
# Out:
# Class distribution in training set:
# label
# 1inch.io               5
# 20thcenturystudios     5
# slate                  5
# scholarpedia           5
# revolut                5
#                       ..
# doi.org                5
# disneystore            5
# disneyplus             5
# disneymovieinsiders    5
# youradchoices          5
# Name: count, Length: 128, dtype: int64
#
# Smallest class has 5 samples
# Using 3-fold cross-validation

# %%
# Initialize and train Bagging Classifier
print("\nTraining Bagging Classifier...")
bag_clf = BaggingClassifier(
    n_estimators=150,
    max_samples=0.8,    
    max_features=0.8,   
    random_state=42,
    n_jobs=-1
)

# Perform cross-validation if possible
if n_splits > 1:
    print(f"\nPerforming {n_splits}-fold cross-validation...")
    try:
        # cv_scores = cross_val_score(bag_clf, X_train_top, y_train, cv=n_splits)
        cv_scores = cross_val_score(bag_clf, X_top, y, cv=n_splits)
        print(f"Cross-validation scores: {cv_scores}")
        print(f"Average CV score: {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")
    except ValueError as e:
        print(f"Could not perform cross-validation: {e}")
else:
    print("\nNot enough samples for cross-validation")
# Out:
# Training Bagging Classifier...
#
# Performing 3-fold cross-validation...
# Cross-validation scores: [0.71962617 0.71361502 0.66666667]
# Average CV score: 0.7000 (+/- 0.0474)

# %%
bag_clf.fit(X_top, y)

# Make predictions on test set
test_predictions = bag_clf.predict(test_df_top)

# Make predictions with both models on test data
print("\nComparing Random Forest and Bagging Classifier on test data...")

# Random Forest predictions
rf_test_predictions = rf_model.predict(X_test)
print("\nRandom Forest Performance on Test Set:")
print("\nClassification Report:")
print(classification_report(y_test, rf_test_predictions))
rf_accuracy = accuracy_score(y_test, rf_test_predictions)

# Bagging Classifier predictions
bag_test_predictions = bag_clf.predict(test_df_top)
print("\nBagging Classifier Performance on Test Set:")
print("\nClassification Report:")
print(classification_report(y_test, bag_test_predictions))
bag_accuracy = accuracy_score(y_test, bag_test_predictions)

# Compare accuracies
print("\nModel Comparison on Test Set:")
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print(f"Bagging Classifier Accuracy: {bag_accuracy:.4f}")
print(f"Difference: {abs(rf_accuracy - bag_accuracy):.4f}")
# Out:
# Comparing Random Forest and Bagging Classifier on test data...
#
# Random Forest Performance on Test Set:
#
# Classification Report:
#                        precision    recall  f1-score   support
#
#              1inch.io       0.50      0.40      0.44         5
#    20thcenturystudios       1.00      0.60      0.75         5
#               YouTube       1.00      0.60      0.75         5
#         aboutads.info       0.67      0.80      0.73         5
#    adventuresbydisney       0.80      0.80      0.80         5
# alainelkanninterviews       1.00      1.00      1.00         5
#            algemeiner       0.75      0.60      0.67         5
#             amazonaws       0.71      1.00      0.83         5
#                 apple       0.60      0.60      0.60         5
#           arstechnica       0.36      0.80      0.50         5
#        atlantis-press       1.00      0.80      0.89         5
#                 axios       0.33      0.60      0.43         5
#                   bbc       0.60      0.60      0.60         5
#               binance       0.75      0.60      0.67         5
#             bloomberg       0.00      0.00      0.00         5
#  bondprotocol.finance       0.83      1.00      0.91         5
#          braindao.org       0.57      0.80      0.67         5
#             brainfund       0.83      1.00      0.91         5
#            britannica       1.00      0.60      0.75         5
#       businessinsider       0.50      0.20      0.29         5
#              buzzfeed       0.00      0.00      0.00         5
#          buzzfeednews       0.50      0.80      0.62         5
#                ca.gov       1.00      0.20      0.33         5
#               cern.ch       0.83      1.00      0.91         5
#       citizendium.org       0.33      0.20      0.25         5
#                  cnbc       0.83      1.00      0.91         5
#                  cnet       0.50      0.40      0.44         5
#                   cnn       0.33      0.40      0.36         5
#             condenast       0.62      1.00      0.77         5
#   creativecommons.org       1.00      0.60      0.75         5
#           dailymotion       0.83      1.00      0.91         5
#         digitaltrends       0.40      0.40      0.40         5
#               discord       0.20      0.20      0.20         5
#                disney       0.50      0.80      0.62         5
#   disneymovieinsiders       0.44      0.80      0.57         5
#            disneyplus       0.60      0.60      0.60         5
#           disneystore       0.00      0.00      0.00         5
#               doi.org       0.71      1.00      0.83         5
#                  drip       0.60      0.60      0.60         5
#                  dtmg       1.00      1.00      1.00         5
#             economist       0.00      0.00      0.00         5
#        economistgroup       0.60      0.60      0.60         5
#               eia.gov       0.71      1.00      0.83         5
#       encyclopediaapi       1.00      1.00      1.00         5
#               epa.gov       1.00      0.40      0.57         5
#                  espn       0.00      0.00      0.00         5
#              facebook       0.00      0.00      0.00         5
#           factmonster       0.50      0.80      0.62         5
#               factset       1.00      0.80      0.89         5
#       familyeducation       0.40      0.40      0.40         5
#           fastcompany       0.67      0.80      0.73         5
#                flickr       0.56      1.00      0.71         5
#             flipboard       0.50      0.60      0.55         5
#                forbes       0.50      0.40      0.44         5
#           foxbusiness       1.00      0.40      0.57         5
#               foxnews       1.00      0.40      0.57         5
#            foxweather       0.50      0.60      0.55         5
#          frax.finance       0.67      0.40      0.50         5
#                github       0.33      0.20      0.25         5
#               gizmodo       1.00      0.60      0.75         5
#                    go       0.00      0.00      0.00         5
#                google       0.45      1.00      0.62         5
#      googleadservices       1.00      0.80      0.89         5
#               govt.nz       0.83      1.00      0.91         5
#        huffingtonpost       0.50      0.20      0.29         5
#              huffpost       0.50      1.00      0.67         5
#           independent       0.45      1.00      0.62         5
#            infoplease       0.67      0.40      0.50         5
#             instagram       0.38      0.60      0.46         5
#               iq.wiki       0.38      0.60      0.46         5
#           israelhayom       1.00      0.80      0.89         5
#                 jpost       0.56      1.00      0.71         5
#              linkedin       1.00      0.20      0.33         5
#                  mako       0.50      0.40      0.44         5
#                marvel       0.71      1.00      0.83         5
#       merriam-webster       0.75      0.60      0.67         5
#        moviesanywhere       0.60      0.60      0.60         5
#    nationalgeographic       0.80      0.80      0.80         5
#                nature       0.40      0.40      0.40         5
#               nbcnews       0.80      0.80      0.80         5
#                  ndtv       0.62      1.00      0.77         5
#              newsweek       0.33      0.40      0.36         5
#             newyorker       0.50      0.40      0.44         5
#                   npr       0.75      0.60      0.67         5
#               nytimes       1.00      0.80      0.89         5
#                odysee       1.00      1.00      1.00         5
#               outkick       0.17      0.20      0.18         5
#                 pcmag       0.57      0.80      0.67         5
#             pinterest       1.00      0.20      0.33         5
#              politico       0.67      0.40      0.50         5
#                reddit       0.00      0.00      0.00         5
#             resources       0.38      1.00      0.56         5
#               revolut       0.80      0.80      0.80         5
#          scholarpedia       0.83      1.00      0.91         5
#                 slate       0.50      0.20      0.29         5
#               spotify       0.50      0.40      0.44         5
#           squarespace       0.38      0.60      0.46         5
#                  ssrn       0.71      1.00      0.83         5
#              starwars       0.62      1.00      0.77         5
#              substack       0.67      0.80      0.73         5
#                  t.me       0.75      0.60      0.67         5
#         teachervision       0.80      0.80      0.80         5
#      technologyreview       0.71      1.00      0.83         5
#             techradar       0.20      0.20      0.20         5
#                   ted       0.71      1.00      0.83         5
#           theguardian       0.67      0.40      0.50         5
#  thewaltdisneycompany       0.75      0.60      0.67         5
#                tiktok       1.00      0.80      0.89         5
#          tomshardware       0.33      0.60      0.43         5
#                tubitv       1.00      0.80      0.89         5
#                twitch       1.00      0.20      0.33         5
#               twitter       0.00      0.00      0.00         5
#                 upbit       1.00      0.40      0.57         5
#              usda.gov       1.00      1.00      1.00         5
#                  veoh       1.00      1.00      1.00         5
#                 vimeo       1.00      1.00      1.00         5
#                    vk       1.00      1.00      1.00         5
#                   vox       0.00      0.00      0.00         5
#               vulture       0.50      0.40      0.44         5
#                 walla       0.75      0.60      0.67         5
#         wikimedia.org       0.00      0.00      0.00         5
#         wikipedia.org       0.57      0.80      0.67         5
#                 wired       0.75      0.60      0.67         5
#             wprdc.org       1.00      1.00      1.00         5
#                     x       0.50      0.40      0.44         5
#           ycombinator       1.00      0.80      0.89         5
#                  ynet       0.60      0.60      0.60         5
#         youradchoices       0.80      0.80      0.80         5
#
#              accuracy                           0.62       640
#             macro avg       0.63      0.62      0.59       640
#          weighted avg       0.63      0.62      0.59       640
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\anconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Bagging Classifier Performance on Test Set:
#
# Classification Report:
#                        precision    recall  f1-score   support
#
#              1inch.io       0.60      0.60      0.60         5
#    20thcenturystudios       1.00      0.60      0.75         5
#               YouTube       1.00      0.60      0.75         5
#         aboutads.info       1.00      1.00      1.00         5
#    adventuresbydisney       0.56      1.00      0.71         5
# alainelkanninterviews       1.00      1.00      1.00         5
#            algemeiner       1.00      1.00      1.00         5
#             amazonaws       1.00      1.00      1.00         5
#                 apple       1.00      0.80      0.89         5
#           arstechnica       0.62      1.00      0.77         5
#        atlantis-press       1.00      0.80      0.89         5
#                 axios       0.60      0.60      0.60         5
#                   bbc       1.00      0.80      0.89         5
#               binance       0.62      1.00      0.77         5
#             bloomberg       0.50      0.20      0.29         5
#  bondprotocol.finance       1.00      1.00      1.00         5
#          braindao.org       0.71      1.00      0.83         5
#             brainfund       0.80      0.80      0.80         5
#            britannica       0.67      0.40      0.50         5
#       businessinsider       1.00      0.40      0.57         5
#              buzzfeed       0.33      0.60      0.43         5
#          buzzfeednews       0.00      0.00      0.00         5
#                ca.gov       1.00      0.20      0.33         5
#               cern.ch       1.00      1.00      1.00         5
#       citizendium.org       0.71      1.00      0.83         5
#                  cnbc       1.00      1.00      1.00         5
#                  cnet       1.00      0.80      0.89         5
#                   cnn       1.00      0.80      0.89         5
#             condenast       1.00      1.00      1.00         5
#   creativecommons.org       0.67      0.40      0.50         5
#           dailymotion       1.00      1.00      1.00         5
#         digitaltrends       0.57      0.80      0.67         5
#               discord       1.00      1.00      1.00         5
#                disney       0.75      0.60      0.67         5
#   disneymovieinsiders       0.83      1.00      0.91         5
#            disneyplus       0.83      1.00      0.91         5
#           disneystore       1.00      0.80      0.89         5
#               doi.org       0.62      1.00      0.77         5
#                  drip       0.80      0.80      0.80         5
#                  dtmg       0.83      1.00      0.91         5
#             economist       0.50      0.20      0.29         5
#        economistgroup       0.71      1.00      0.83         5
#               eia.gov       0.83      1.00      0.91         5
#       encyclopediaapi       1.00      0.80      0.89         5
#               epa.gov       1.00      0.20      0.33         5
#                  espn       1.00      0.60      0.75         5
#              facebook       0.40      0.40      0.40         5
#           factmonster       1.00      1.00      1.00         5
#               factset       1.00      0.80      0.89         5
#       familyeducation       1.00      0.60      0.75         5
#           fastcompany       1.00      0.80      0.89         5
#                flickr       0.56      1.00      0.71         5
#             flipboard       0.80      0.80      0.80         5
#                forbes       0.83      1.00      0.91         5
#           foxbusiness       1.00      0.40      0.57         5
#               foxnews       0.00      0.00      0.00         5
#            foxweather       0.57      0.80      0.67         5
#          frax.finance       0.83      1.00      0.91         5
#                github       1.00      0.20      0.33         5
#               gizmodo       0.62      1.00      0.77         5
#                    go       1.00      0.20      0.33         5
#                google       0.67      0.80      0.73         5
#      googleadservices       0.83      1.00      0.91         5
#               govt.nz       0.83      1.00      0.91         5
#        huffingtonpost       0.50      0.40      0.44         5
#              huffpost       0.17      0.20      0.18         5
#           independent       1.00      1.00      1.00         5
#            infoplease       1.00      0.80      0.89         5
#             instagram       0.25      0.20      0.22         5
#               iq.wiki       1.00      0.40      0.57         5
#           israelhayom       1.00      1.00      1.00         5
#                 jpost       0.83      1.00      0.91         5
#              linkedin       1.00      0.40      0.57         5
#                  mako       0.80      0.80      0.80         5
#                marvel       1.00      1.00      1.00         5
#       merriam-webster       1.00      1.00      1.00         5
#        moviesanywhere       1.00      0.80      0.89         5
#    nationalgeographic       1.00      1.00      1.00         5
#                nature       1.00      0.80      0.89         5
#               nbcnews       1.00      1.00      1.00         5
#                  ndtv       1.00      1.00      1.00         5
#              newsweek       1.00      0.80      0.89         5
#             newyorker       1.00      1.00      1.00         5
#                   npr       0.80      0.80      0.80         5
#               nytimes       0.71      1.00      0.83         5
#                odysee       1.00      0.80      0.89         5
#               outkick       0.29      0.40      0.33         5
#                 pcmag       0.60      0.60      0.60         5
#             pinterest       1.00      0.80      0.89         5
#              politico       0.80      0.80      0.80         5
#                reddit       1.00      0.60      0.75         5
#             resources       0.62      1.00      0.77         5
#               revolut       0.80      0.80      0.80         5
#          scholarpedia       0.71      1.00      0.83         5
#                 slate       1.00      1.00      1.00         5
#               spotify       0.83      1.00      0.91         5
#           squarespace       1.00      0.80      0.89         5
#                  ssrn       0.71      1.00      0.83         5
#              starwars       0.62      1.00      0.77         5
#              substack       0.83      1.00      0.91         5
#                  t.me       0.40      0.40      0.40         5
#         teachervision       0.62      1.00      0.77         5
#      technologyreview       1.00      1.00      1.00         5
#             techradar       1.00      1.00      1.00         5
#                   ted       1.00      1.00      1.00         5
#           theguardian       1.00      0.60      0.75         5
#  thewaltdisneycompany       0.75      0.60      0.67         5
#                tiktok       0.33      0.20      0.25         5
#          tomshardware       1.00      1.00      1.00         5
#                tubitv       1.00      0.80      0.89         5
#                twitch       0.71      1.00      0.83         5
#               twitter       1.00      0.60      0.75         5
#                 upbit       0.83      1.00      0.91         5
#              usda.gov       1.00      1.00      1.00         5
#                  veoh       1.00      1.00      1.00         5
#                 vimeo       0.71      1.00      0.83         5
#                    vk       0.83      1.00      0.91         5
#                   vox       0.56      1.00      0.71         5
#               vulture       1.00      0.60      0.75         5
#                 walla       1.00      1.00      1.00         5
#         wikimedia.org       0.00      0.00      0.00         5
#         wikipedia.org       0.56      1.00      0.71         5
#                 wired       0.71      1.00      0.83         5
#             wprdc.org       0.56      1.00      0.71         5
#                     x       0.71      1.00      0.83         5
#           ycombinator       0.67      0.80      0.73         5
#                  ynet       0.80      0.80      0.80         5
#         youradchoices       0.71      1.00      0.83         5
#
#              accuracy                           0.78       640
#             macro avg       0.80      0.78      0.77       640
#          weighted avg       0.80      0.78      0.77       640
#
#
# Model Comparison on Test Set:
# Random Forest Accuracy: 0.6172
# Bagging Classifier Accuracy: 0.7844
# Difference: 0.1672

# %%
# # Create label encoder for target variable
# le_target = LabelEncoder()
# y_encoded = le_target.fit_transform(y)
# test_labels_encoded = le_target.transform(y_test)

# # XGBoost
# print("\nTraining XGBoost model...")
# xgb_model = XGBClassifier(
#     n_estimators=100,
#     learning_rate=0.1,
#     max_depth=7,
#     random_state=42,
#     n_jobs=-1
# )
# xgb_model.fit(X_top, y_encoded)

# # LightGBM
# print("\nTraining LightGBM model...")
# lgb_model = LGBMClassifier(
#     n_estimators=100,
#     learning_rate=0.1,
#     num_leaves=31,
#     random_state=42,
#     n_jobs=-1
# )
# lgb_model.fit(X_top, y_encoded)

# # CatBoost
# print("\nTraining CatBoost model...")
# cat_model = CatBoostClassifier(
#     iterations=100,
#     learning_rate=0.1,
#     depth=7,
#     random_seed=42,
#     verbose=False
# )
# cat_model.fit(X_top, y_encoded)

# # Voting Classifier
# print("\nTraining Voting Classifier...")
# voting_clf = VotingClassifier(
#     estimators=[
#         ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
#         ('xgb', XGBClassifier(n_estimators=100, random_state=42)),
#         ('lgb', LGBMClassifier(n_estimators=100, random_state=42))
#     ],
#     voting='soft'
# )
# voting_clf.fit(X_top, y_encoded)

# # Stacking Classifier
# print("\nTraining Stacking Classifier...")
# estimators = [
#     ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
#     ('xgb', XGBClassifier(n_estimators=100, random_state=42)),
#     ('lgb', LGBMClassifier(n_estimators=100, random_state=42))
# ]
# stack_clf = StackingClassifier(
#     estimators=estimators,
#     final_estimator=LogisticRegression(),
#     cv=3
# )
# stack_clf.fit(X_top, y_encoded)

# # Make predictions and convert back to original labels
# # XGBoost
# xgb_test_predictions = le_target.inverse_transform(xgb_model.predict(test_df_top))
# xgb_accuracy = accuracy_score(y_test, xgb_test_predictions)
# print("\nXGBoost Performance:")
# print(classification_report(y_test, xgb_test_predictions))

# # LightGBM
# lgb_test_predictions = le_target.inverse_transform(lgb_model.predict(test_df_top))
# lgb_accuracy = accuracy_score(y_test, lgb_test_predictions)
# print("\nLightGBM Performance:")
# print(classification_report(y_test, lgb_test_predictions))

# # CatBoost
# cat_test_predictions = le_target.inverse_transform(cat_model.predict(test_df_top))
# cat_accuracy = accuracy_score(y_test, cat_test_predictions)
# print("\nCatBoost Performance:")
# print(classification_report(y_test, cat_test_predictions))

# # Voting Classifier
# voting_test_predictions = le_target.inverse_transform(voting_clf.predict(test_df_top))
# voting_accuracy = accuracy_score(y_test, voting_test_predictions)
# print("\nVoting Classifier Performance:")
# print(classification_report(y_test, voting_test_predictions))

# # Stacking Classifier
# stack_test_predictions = le_target.inverse_transform(stack_clf.predict(test_df_top))
# stack_accuracy = accuracy_score(y_test, stack_test_predictions)
# print("\nStacking Classifier Performance:")
# print(classification_report(y_test, stack_test_predictions))

# # Final comparison
# print("\nFinal Model Comparison (Test Set Accuracy):")
# print(f"Random Forest:       {rf_accuracy:.4f}")
# print(f"Bagging Classifier:  {bag_accuracy:.4f}")
# print(f"XGBoost:            {xgb_accuracy:.4f}")
# print(f"LightGBM:           {lgb_accuracy:.4f}")
# print(f"CatBoost:           {cat_accuracy:.4f}")
# print(f"Voting Classifier:   {voting_accuracy:.4f}")
# print(f"Stacking Classifier: {stack_accuracy:.4f}")
