# %% [markdown]
# # FlowPic CNN-Model
# ### This notebook run the non-vpn datas in non-weighted-class with CNN-Model

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
#  ~~~~
#  Tests-results:
#  ~~~~
# ##### win-60: 0.978%
# ##### win-60 25% overlap: 0.989%
# ##### win-60 75% overlap: 0.989%
# ##### win-30: 0.915%
# ##### win-10: 0.931%

# %% [markdown]
# ~~~~~~~~~~~~~~

# %% [markdown]
# ~~~~
# cnn-model parameters:
# ~~~~
# ###### 1. Conv_layer= (10, kernel=(10, 10),strides= 5)
# ###### 2. MaxPooling2D = (2, 2)
# ###### 3. Conv_layer= (20, kernel=(10, 10),strides= 5)
# ###### 4. Dropout = 0.25
# ###### 5. MaxPooling2D = (2, 2)
# ###### 6. Flatten
# ###### 7. Dense 64
# ###### 8. Dropout = 0.5
# ###### 9. Output Dense = num_classes

# %% [markdown]
# ~~~~~~~~

# %% [markdown]
# ##### Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import top_k_categorical_accuracy, Precision, Recall
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import time
from datetime import timedelta
import os

# %% [markdown]
# ##### functions

# %%
class CNNDatasetEvaluator:
    def __init__(self, height=1500, width=1500, channels=1):
        """
        Initialize the evaluator with default image dimensions
        
        Parameters:
        - height: Image height
        - width: Image width
        - channels: Number of image channels
        """
        self.height = height
        self.width = width
        self.channels = channels
        self.input_shape = (self.channels, self.height, self.width)
        
        # Default model parameters
        self._conv_layers = [(10, (10, 10), 5), (20, (10, 10), 5)]  # Convolutional layers
        self._dropout_rates = [0.25, 0.5]  # Dropout rates
        self._dense_layers = [64]  # Dense layers

    def compute_class_weights(self, y_train):
        """
        Compute class weights for imbalanced datasets.
        
        Parameters:
        - y_train: Training labels (integer format, not one-hot encoded)
        
        Returns:
        - class_weights: Dictionary of class weights
        """
        # Convert one-hot encoded labels to integer format if necessary
        if len(y_train.shape) > 1 and y_train.shape[1] > 1:
            y_train = np.argmax(y_train, axis=1)
        
        classes = np.unique(y_train)
        class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
        return dict(zip(classes, class_weights))
    
    def top_2_categorical_accuracy(self, y_true, y_pred):
        """Custom top-2 categorical accuracy metric"""
        return top_k_categorical_accuracy(y_true, y_pred, k=2)
    
    def build_model(self, num_classes):
        """
        Build CNN model with flexible architecture
        
        Parameters:
        - num_classes: Number of output classes
        """
        model = Sequential()
        
        # First convolutional layer
        model.add(Conv2D(self._conv_layers[0][0], 
                         kernel_size=self._conv_layers[0][1], 
                         strides=self._conv_layers[0][2], 
                         padding="same", 
                         data_format='channels_last', 
                         input_shape=self.input_shape))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2), padding="same", data_format='channels_last'))
        
        # Additional convolutional layers
        for filters, kernel_size, stride in self._conv_layers[1:]:
            model.add(Conv2D(filters, 
                             kernel_size=kernel_size, 
                             strides=stride, 
                             padding="same", 
                             data_format='channels_last'))
            model.add(Activation('relu'))
            model.add(Dropout(self._dropout_rates[0]))
            model.add(MaxPooling2D(pool_size=(2, 2), padding="same", data_format='channels_last'))
        
        # Flatten and dense layers
        model.add(Flatten())
        for neurons in self._dense_layers:
            model.add(Dense(neurons, activation='relu'))
            model.add(Dropout(self._dropout_rates[1]))
        
        # Output layer
        model.add(Dense(num_classes, activation='softmax'))
        
        return model
    
    def prepare_data(self, X, y, num_classes):
        """
        Prepare data for training
        
        Parameters:
        - X: Input features
        - y: Input labels
        - num_classes: Number of classes
        
        Returns:
        - Processed X and one-hot encoded y
        """
        # Expand dimensions if needed
        if len(X.shape) == 3:
            X = np.expand_dims(X, axis=1)
        elif len(X.shape) != 4:
            raise ValueError(f"Input data must be 3D or 4D, but got shape {X.shape}")
        
        # One-hot encode labels
        y_categorical = to_categorical(y, num_classes)
        
        return X, y_categorical
    
    def train_and_evaluate(self, X_train, y_train, X_val, y_val, X_test, y_test, 
                       class_names=None, 
                       batch_size=128, 
                       epochs=20, 
                       samples_per_epoch=10,
                       use_class_weights=False):
        """
        Train and evaluate the model on given datasets
        
        Parameters:
        - X_train, y_train: Training data
        - X_val, y_val: Validation data
        - X_test, y_test: Test data
        - class_names: Optional list of class names
        - batch_size: Training batch size
        - epochs: Number of training epochs
        - samples_per_epoch: Samples per epoch for generator
        - use_class_weights: Whether to compute and use class weights for imbalanced datasets
        
        Returns:
        - Dictionary with training results
        """
        # Determine number of classes
        num_classes = len(np.unique(y_train))
        
        # Prepare data
        X_train, y_train = self.prepare_data(X_train, y_train, num_classes)
        X_val, y_val = self.prepare_data(X_val, y_val, num_classes)
        X_test, y_test = self.prepare_data(X_test, y_test, num_classes)
        
        # Compute class weights if requested
        class_weights = None
        if use_class_weights:
            y_train_classes = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train
            class_weights = self.compute_class_weights(y_train_classes)
        
        # Build model
        model = self.build_model(num_classes)
        
        # Compile model
        model.compile(
            loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy', self.top_2_categorical_accuracy, Precision(), Recall()]
        )
        
        # Callbacks
        callbacks = [
            EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=3,
                min_lr=1e-6
            ),
            TensorBoard(log_dir='./Graph', histogram_freq=1, write_graph=True, write_images=True)
        ]
        
        # Simple generator
        def generator(features, labels, batch_size):
            index = 0
            while True:
                index += batch_size
                if index >= len(features):
                    batch_features = np.append(features[index - batch_size:len(features)], 
                                               features[0:index - len(features)], axis=0)
                    batch_labels = np.append(labels[index - batch_size:len(features)], 
                                             labels[0:index - len(features)], axis=0)
                    index -= len(features)
                    yield batch_features, batch_labels
                else:
                    yield features[index - batch_size:index], labels[index - batch_size:index]

        def weighted_generator(features, labels, batch_size, class_weights):
            index = 0
            num_samples = len(features)
            while True:
                index += batch_size
                if index >= num_samples:
                    batch_features = np.append(features[index - batch_size:num_samples], 
                                               features[0:index - num_samples], axis=0)
                    batch_labels = np.append(labels[index - batch_size:num_samples], 
                                             labels[0:index - num_samples], axis=0)
                    index -= num_samples
                else:
                    batch_features = features[index - batch_size:index]
                    batch_labels = labels[index - batch_size:index]
                
                # Compute sample weights based on class weights
                sample_weights = np.array([class_weights[np.argmax(label)] for label in batch_labels])
                
                yield batch_features, batch_labels, sample_weights
        
        # Train model
        start_time = time.time()
        if use_class_weights:
            # Use the weighted generator
            train_gen = weighted_generator(X_train, y_train, batch_size, class_weights)
            history = model.fit(
                train_gen,
                epochs=epochs,
                steps_per_epoch=samples_per_epoch,
                verbose=1,
                callbacks=callbacks,
                validation_data=(X_val, y_val)
            )
        else:
        # Use the original generator
            train_gen = generator(X_train, y_train, batch_size)
            history = model.fit(
                train_gen,
                epochs=epochs,
                steps_per_epoch=samples_per_epoch,
                verbose=1,
                callbacks=callbacks,
                validation_data=(X_val, y_val)
            )
        
        # Calculate training time
        training_time = time.time() - start_time
        
        # Predictions
        y_val_pred = model.predict(X_val)
        y_test_pred = model.predict(X_test)
        
        y_val_pred_classes = np.argmax(y_val_pred, axis=1)
        y_test_pred_classes = np.argmax(y_test_pred, axis=1)
        
        # Convert y_test and y_val from one-hot encoded to integer labels if necessary
        y_val_classes = np.argmax(y_val, axis=1) if len(y_val.shape) > 1 else y_val
        y_test_classes = np.argmax(y_test, axis=1) if len(y_test.shape) > 1 else y_test
        
        # Results
        results = {
            'training_time': timedelta(seconds=training_time),
            'val_classification_report': classification_report(
                y_val_classes, 
                y_val_pred_classes, 
                target_names=class_names
            ),
            'test_classification_report': classification_report(
                y_test_classes, 
                y_test_pred_classes, 
                target_names=class_names
            ),
            'val_accuracy': np.mean(y_val_pred_classes == y_val_classes),
            'test_accuracy': np.mean(y_test_pred_classes == y_test_classes),
            'history': history.history,
            'test_predictions': y_test_pred
        }
        
        return results
    
    # Getter and Setter methods for model parameters
    def get_conv_layers(self):
        """Get the convolutional layers configuration"""
        return self._conv_layers
    
    def set_conv_layers(self, conv_layers):
        """Set the convolutional layers configuration"""
        self._conv_layers = conv_layers
    
    def get_dropout_rates(self):
        """Get the dropout rates"""
        return self._dropout_rates
    
    def set_dropout_rates(self, dropout_rates):
        """Set the dropout rates"""
        self._dropout_rates = dropout_rates
    
    def get_dense_layers(self):
        """Get the dense layers configuration"""
        return self._dense_layers
    
    def set_dense_layers(self, dense_layers):
        """Set the dense layers configuration"""
        self._dense_layers = dense_layers

# %%
def load_data(base_dir, dataset_prefix):
    """
    Load dataset files from a specified directory based on a common prefix.
    
    Parameters:
    - base_dir: Directory where the dataset files are stored
    - dataset_prefix: Common prefix for the dataset files (e.g., 'reg_X_train')
    
    Returns:
    - X_train, y_train, X_val, y_val, X_test, y_test
    """
    try:
        X_train = np.load(f"{base_dir}/reg_X_train{dataset_prefix}.npy")
        y_train = np.load(f"{base_dir}/reg_y_train{dataset_prefix}.npy")
        X_val = np.load(f"{base_dir}/reg_X_val{dataset_prefix}.npy")
        y_val = np.load(f"{base_dir}/reg_y_val{dataset_prefix}.npy")
        X_test = np.load(f"{base_dir}/reg_X_test{dataset_prefix}.npy")
        y_test = np.load(f"{base_dir}/reg_y_test{dataset_prefix}.npy")
    except FileNotFoundError as e:
        print(f"Error loading dataset: {e}")
        return None, None, None, None, None, None
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def plot_confusion_matrix(y_true, y_pred, class_names):
    """
    Plot a confusion matrix.
    
    Parameters:
    - y_true: True labels
    - y_pred: Predicted labels
    - class_names: List of class names
    """
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
def plot_learning_curves(history):
    """
    Plot learning curves (accuracy and loss) for training and validation.
    
    Parameters:
    - history: Training history returned by model.fit()
    """
    # Plot accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Training Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Training Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.show()

# %%
def evaluate_datasets(dataset_info,
                      height,
                      width,
                      channels,
                      class_names,
                      conv_layers=[(10, (10, 10), 5), (20, (10, 10), 5)],
                      dropout_rates=[0.25, 0.5],
                      dense_layers=[64],
                      batch_size=128,
                      epochs=20,
                      samples_per_epoch=10,
                      use_class_weights=False  # Enable class weights
                     ):

    """
    Evaluate the model on multiple datasets from different directories.
    
    Parameters:
    - dataset_info: List of tuples containing (base_dir, dataset_prefix)
    - height, width, channels: Image dimensions
    - class_names: List of class names for classification report
    - conv_layers,dropout_rates,dense_layers: model parameters
    - batch_size, epochs, samples_per_epoch: Training parameters
    - use_class_weights: give weights to classes with less samples
    """
    results = {}
    
    for base_dir, prefix in dataset_info:
        print(f"Evaluating dataset: {prefix} from directory: {base_dir}")
        
        # Load data
        X_train, y_train, X_val, y_val, X_test, y_test = load_data(base_dir, prefix)
        
        # Initialize evaluator
        evaluator = CNNDatasetEvaluator(height=height, width=width, channels=channels)

        # Update parameters
        evaluator.set_conv_layers(conv_layers)
        evaluator.set_dropout_rates(dropout_rates)
        evaluator.set_dense_layers(dense_layers)

        # Verify updated parameters
        print("Conv Layers:", evaluator.get_conv_layers())
        print("Dropout Rates:", evaluator.get_dropout_rates())
        print("Dense Layers:", evaluator.get_dense_layers())

        # Train and evaluate
        result = evaluator.train_and_evaluate(
            X_train, y_train, X_val, y_val, X_test, y_test,
            class_names=class_names,
            batch_size=batch_size,
            epochs=epochs,
            samples_per_epoch=samples_per_epoch,
            use_class_weights=use_class_weights
        )
        
        # Store results
        results[f"{base_dir}/{prefix}"] = result
        
        # Print results
        print(f"Results for {base_dir}/{prefix}:")
        print(f"Training Time: {result['training_time']}")
        print(f"Validation Accuracy: {result['val_accuracy']}")
        print(f"Test Accuracy: {result['test_accuracy']}")
        print("Validation Classification Report:")
        print(result['val_classification_report'])
        print("Test Classification Report:")
        print(result['test_classification_report'])
        print("-" * 80)

        #plot confusion matrix
        if len(y_test.shape) == 1:
            y_test_true = y_test  # Already integer labels
        else:
            y_test_true = np.argmax(y_test, axis=1)  # Convert one-hot to integer labels

        if len(result['test_predictions'].shape) == 1:
            y_test_pred = result['test_predictions']  # Already integer labels
        else:
            y_test_pred = np.argmax(result['test_predictions'], axis=1)  # Convert one-hot to integer labels

        plot_confusion_matrix(y_true=y_test_true, y_pred=y_test_pred, class_names=class_names)

        #plot learning curves
        history = result['history']
        plot_learning_curves(history)
    
    return results

# %% [markdown]
# ##### parameters preper

# %%
# List of datasets with their directories and prefixes
dataset_info = [
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy', ''),  # Dataset 1 in directory 'path/to/dataset1'
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy', '_win60_overlap25'),  # Dataset 2 in directory 'path/to/dataset2'
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75', '_win60_overlap75'),
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win30', '_win30'),
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win10' , '_win10')
]

# %%
batch_size = 128 #128
samples_per_epoch = 10
num_classes = 4
epochs = 20 #20
class_names = ["voip", "video", "file transfer", "chat"]

# input hist dimensions
height, width = 1500, 1500
channels = 1
input_shape = (1, height, width)

# %% [markdown]
# ~~~~~~~
#  fit the model on:
# ~~~~~~~
# ###### 1. win60
# ###### 2. win60 overlap 25%
# ###### 3. win60 overlap 75%
# ###### 4. win 30
# ###### 5. win 10

# %%
# Evaluate datasets
results_1 = evaluate_datasets(
    dataset_info=dataset_info,
    height=height,
    width=width,
    channels=channels,
    class_names=class_names,
    conv_layers= [(10, (10, 10), 5), (20, (10, 10), 5)],
    dropout_rates=[0.25, 0.5],
    dense_layers=[64],
    batch_size=batch_size,
    epochs=epochs,
    samples_per_epoch=samples_per_epoch,
    use_class_weights=False
)
# Out:
# Evaluating dataset:  from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 151s 15s/step - accuracy: 0.4347 - loss: 1.3275 - precision: 0.4344 - recall: 0.0152 - top_2_categorical_accuracy: 0.6451 - val_accuracy: 0.5957 - val_loss: 0.9366 - val_precision: 1.0000 - val_recall: 0.4255 - val_top_2_categorical_accuracy: 0.7589 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.6277 - loss: 0.7754 - precision: 0.9552 - recall: 0.4756 - top_2_categorical_accuracy: 0.7922 - val_accuracy: 0.7021 - val_loss: 0.5397 - val_precision: 1.0000 - val_recall: 0.6667 - val_top_2_categorical_accuracy: 0.7872 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.7579 - loss: 0.4959 - precision: 0.9949 - recall: 0.6583 - top_2_categorical_accuracy: 0.8292 - val_accuracy: 0.7943 - val_loss: 0.4354 - val_precision: 1.0000 - val_recall: 0.6667 - val_top_2_categorical_accuracy: 0.8582 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.8123 - loss: 0.3947 - precision: 0.9805 - recall: 0.7212 - top_2_categorical_accuracy: 0.8938 - val_accuracy: 0.8227 - val_loss: 0.3787 - val_precision: 1.0000 - val_recall: 0.7376 - val_top_2_categorical_accuracy: 0.8652 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.8743 - loss: 0.3130 - precision: 0.9924 - recall: 0.7835 - top_2_categorical_accuracy: 0.8972 - val_accuracy: 0.8227 - val_loss: 0.3433 - val_precision: 0.9906 - val_recall: 0.7447 - val_top_2_categorical_accuracy: 0.8652 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.8805 - loss: 0.2669 - precision: 0.9979 - recall: 0.8071 - top_2_categorical_accuracy: 0.9637 - val_accuracy: 0.8227 - val_loss: 0.3197 - val_precision: 0.9906 - val_recall: 0.7447 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.8826 - loss: 0.2386 - precision: 0.9966 - recall: 0.8276 - top_2_categorical_accuracy: 0.9756 - val_accuracy: 0.8227 - val_loss: 0.2975 - val_precision: 0.9906 - val_recall: 0.7447 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.8887 - loss: 0.2168 - precision: 0.9881 - recall: 0.8315 - top_2_categorical_accuracy: 0.9853 - val_accuracy: 0.8227 - val_loss: 0.2756 - val_precision: 0.9907 - val_recall: 0.7589 - val_top_2_categorical_accuracy: 0.9574 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8841 - loss: 0.2047 - precision: 0.9810 - recall: 0.8319 - top_2_categorical_accuracy: 0.9813 - val_accuracy: 0.9291 - val_loss: 0.2617 - val_precision: 0.9912 - val_recall: 0.7943 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 147s 15s/step - accuracy: 0.9284 - loss: 0.1737 - precision: 0.9966 - recall: 0.8515 - top_2_categorical_accuracy: 0.9872 - val_accuracy: 0.9716 - val_loss: 0.2407 - val_precision: 0.9912 - val_recall: 0.8014 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.9612 - loss: 0.1481 - precision: 0.9952 - recall: 0.8906 - top_2_categorical_accuracy: 0.9895 - val_accuracy: 0.9716 - val_loss: 0.2169 - val_precision: 0.9833 - val_recall: 0.8369 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.9705 - loss: 0.1263 - precision: 0.9790 - recall: 0.9321 - top_2_categorical_accuracy: 0.9921 - val_accuracy: 0.9716 - val_loss: 0.1907 - val_precision: 0.9784 - val_recall: 0.9645 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.9785 - loss: 0.1100 - precision: 0.9877 - recall: 0.9517 - top_2_categorical_accuracy: 0.9914 - val_accuracy: 0.9787 - val_loss: 0.1784 - val_precision: 0.9786 - val_recall: 0.9716 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.9828 - loss: 0.0911 - precision: 0.9909 - recall: 0.9703 - top_2_categorical_accuracy: 0.9921 - val_accuracy: 0.9787 - val_loss: 0.1705 - val_precision: 0.9786 - val_recall: 0.9716 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.9858 - loss: 0.0830 - precision: 0.9879 - recall: 0.9794 - top_2_categorical_accuracy: 0.9937 - val_accuracy: 0.9787 - val_loss: 0.1566 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.9829 - loss: 0.0685 - precision: 0.9874 - recall: 0.9785 - top_2_categorical_accuracy: 0.9966 - val_accuracy: 0.9787 - val_loss: 0.1466 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9840 - loss: 0.0637 - precision: 0.9849 - recall: 0.9835 - top_2_categorical_accuracy: 0.9969 - val_accuracy: 0.9787 - val_loss: 0.1433 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9809 - loss: 0.0619 - precision: 0.9834 - recall: 0.9807 - top_2_categorical_accuracy: 0.9938 - val_accuracy: 0.9787 - val_loss: 0.1446 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 148s 15s/step - accuracy: 0.9841 - loss: 0.0588 - precision: 0.9846 - recall: 0.9826 - top_2_categorical_accuracy: 0.9965 - val_accuracy: 0.9787 - val_loss: 0.1476 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9862 - loss: 0.0610 - precision: 0.9873 - recall: 0.9854 - top_2_categorical_accuracy: 0.9953 - val_accuracy: 0.9787 - val_loss: 0.1478 - val_precision: 0.9787 - val_recall: 0.9787 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 684ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 650ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/:
# Training Time: 0:46:42.300094
# Validation Accuracy: 0.9787234042553191
# Test Accuracy: 0.9787234042553191
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.95      1.00      0.97        19
#         video       1.00      0.93      0.96        27
# file transfer       0.99      1.00      0.99        80
#          chat       0.93      0.93      0.93        15
#
#      accuracy                           0.98       141
#     macro avg       0.97      0.96      0.97       141
#  weighted avg       0.98      0.98      0.98       141
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.92      1.00      0.96        23
#         video       1.00      0.97      0.98        30
# file transfer       0.99      0.99      0.99        72
#          chat       1.00      0.94      0.97        16
#
#      accuracy                           0.98       141
#     macro avg       0.98      0.97      0.97       141
#  weighted avg       0.98      0.98      0.98       141
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win60_overlap25 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.4830 - loss: 1.3016 - precision_1: 0.4810 - recall_1: 0.0399 - top_2_categorical_accuracy: 0.6968 - val_accuracy: 0.5067 - val_loss: 0.9006 - val_precision_1: 0.8219 - val_recall_1: 0.4000 - val_top_2_categorical_accuracy: 0.7133 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6024 - loss: 0.7502 - precision_1: 0.9000 - recall_1: 0.5064 - top_2_categorical_accuracy: 0.7841 - val_accuracy: 0.6133 - val_loss: 0.6281 - val_precision_1: 0.9785 - val_recall_1: 0.6067 - val_top_2_categorical_accuracy: 0.7333 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.7358 - loss: 0.4915 - precision_1: 0.9970 - recall_1: 0.6719 - top_2_categorical_accuracy: 0.8011 - val_accuracy: 0.7267 - val_loss: 0.5390 - val_precision_1: 0.9787 - val_recall_1: 0.6133 - val_top_2_categorical_accuracy: 0.7333 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.7921 - loss: 0.4190 - precision_1: 0.9976 - recall_1: 0.6934 - top_2_categorical_accuracy: 0.8616 - val_accuracy: 0.7533 - val_loss: 0.4854 - val_precision_1: 0.9806 - val_recall_1: 0.6733 - val_top_2_categorical_accuracy: 0.8467 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.8494 - loss: 0.3629 - precision_1: 0.9991 - recall_1: 0.7345 - top_2_categorical_accuracy: 0.9045 - val_accuracy: 0.8267 - val_loss: 0.4237 - val_precision_1: 0.9811 - val_recall_1: 0.6933 - val_top_2_categorical_accuracy: 0.8400 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.8934 - loss: 0.3034 - precision_1: 0.9998 - recall_1: 0.7767 - top_2_categorical_accuracy: 0.9257 - val_accuracy: 0.8267 - val_loss: 0.3726 - val_precision_1: 0.9817 - val_recall_1: 0.7133 - val_top_2_categorical_accuracy: 0.9600 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.9096 - loss: 0.2491 - precision_1: 1.0000 - recall_1: 0.8024 - top_2_categorical_accuracy: 0.9609 - val_accuracy: 0.9533 - val_loss: 0.3291 - val_precision_1: 0.9818 - val_recall_1: 0.7200 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9177 - loss: 0.2146 - precision_1: 0.9952 - recall_1: 0.8111 - top_2_categorical_accuracy: 0.9874 - val_accuracy: 0.9200 - val_loss: 0.2886 - val_precision_1: 0.9820 - val_recall_1: 0.7267 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9326 - loss: 0.1863 - precision_1: 0.9808 - recall_1: 0.8447 - top_2_categorical_accuracy: 0.9939 - val_accuracy: 0.9533 - val_loss: 0.2608 - val_precision_1: 0.9912 - val_recall_1: 0.7467 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9393 - loss: 0.1649 - precision_1: 0.9742 - recall_1: 0.8862 - top_2_categorical_accuracy: 0.9969 - val_accuracy: 0.9533 - val_loss: 0.2397 - val_precision_1: 0.9915 - val_recall_1: 0.7800 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9511 - loss: 0.1507 - precision_1: 0.9733 - recall_1: 0.9136 - top_2_categorical_accuracy: 0.9941 - val_accuracy: 0.9600 - val_loss: 0.2362 - val_precision_1: 0.9726 - val_recall_1: 0.9467 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 147s 15s/step - accuracy: 0.9693 - loss: 0.1306 - precision_1: 0.9814 - recall_1: 0.9408 - top_2_categorical_accuracy: 0.9932 - val_accuracy: 0.9667 - val_loss: 0.2205 - val_precision_1: 0.9662 - val_recall_1: 0.9533 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9831 - loss: 0.1074 - precision_1: 0.9860 - recall_1: 0.9630 - top_2_categorical_accuracy: 0.9959 - val_accuracy: 0.9667 - val_loss: 0.2029 - val_precision_1: 0.9664 - val_recall_1: 0.9600 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9913 - loss: 0.0721 - precision_1: 0.9922 - recall_1: 0.9844 - top_2_categorical_accuracy: 0.9971 - val_accuracy: 0.9667 - val_loss: 0.1862 - val_precision_1: 0.9664 - val_recall_1: 0.9600 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9878 - loss: 0.0633 - precision_1: 0.9888 - recall_1: 0.9878 - top_2_categorical_accuracy: 0.9961 - val_accuracy: 0.9667 - val_loss: 0.1726 - val_precision_1: 0.9664 - val_recall_1: 0.9600 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.9915 - loss: 0.0546 - precision_1: 0.9914 - recall_1: 0.9888 - top_2_categorical_accuracy: 0.9985 - val_accuracy: 0.9667 - val_loss: 0.1840 - val_precision_1: 0.9732 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9910 - loss: 0.0446 - precision_1: 0.9912 - recall_1: 0.9910 - top_2_categorical_accuracy: 0.9974 - val_accuracy: 0.9733 - val_loss: 0.1894 - val_precision_1: 0.9730 - val_recall_1: 0.9600 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9958 - loss: 0.0340 - precision_1: 0.9958 - recall_1: 0.9958 - top_2_categorical_accuracy: 1.0000 - val_accuracy: 0.9733 - val_loss: 0.1908 - val_precision_1: 0.9730 - val_recall_1: 0.9600 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9897 - loss: 0.0380 - precision_1: 0.9908 - recall_1: 0.9883 - top_2_categorical_accuracy: 0.9978 - val_accuracy: 0.9733 - val_loss: 0.1890 - val_precision_1: 0.9732 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 2.0000e-04
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.9897 - loss: 0.0441 - precision_1: 0.9897 - recall_1: 0.9897 - top_2_categorical_accuracy: 0.9970 - val_accuracy: 0.9733 - val_loss: 0.1864 - val_precision_1: 0.9732 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 2.0000e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 715ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 734ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/_win60_overlap25:
# Training Time: 0:46:25.501548
# Validation Accuracy: 0.9666666666666667
# Test Accuracy: 0.9893048128342246
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.85      1.00      0.92        23
#         video       1.00      0.90      0.95        31
# file transfer       0.99      1.00      0.99        76
#          chat       1.00      0.90      0.95        20
#
#      accuracy                           0.97       150
#     macro avg       0.96      0.95      0.95       150
#  weighted avg       0.97      0.97      0.97       150
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.92      1.00      0.96        24
#         video       1.00      0.97      0.99        36
# file transfer       1.00      1.00      1.00       101
#          chat       1.00      0.96      0.98        26
#
#      accuracy                           0.99       187
#     macro avg       0.98      0.98      0.98       187
#  weighted avg       0.99      0.99      0.99       187
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win60_overlap75 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.4196 - loss: 1.3216 - precision_2: 0.3536 - recall_2: 0.0211 - top_2_categorical_accuracy: 0.6195 - val_accuracy: 0.5481 - val_loss: 0.9012 - val_precision_2: 0.9360 - val_recall_2: 0.4251 - val_top_2_categorical_accuracy: 0.7942 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 15s/step - accuracy: 0.5759 - loss: 0.8216 - precision_2: 0.9142 - recall_2: 0.4471 - top_2_categorical_accuracy: 0.7890 - val_accuracy: 0.7181 - val_loss: 0.6161 - val_precision_2: 0.9918 - val_recall_2: 0.5414 - val_top_2_categorical_accuracy: 0.7964 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.7668 - loss: 0.5291 - precision_2: 0.9958 - recall_2: 0.6402 - top_2_categorical_accuracy: 0.8158 - val_accuracy: 0.7987 - val_loss: 0.4457 - val_precision_2: 0.9967 - val_recall_2: 0.6823 - val_top_2_categorical_accuracy: 0.8747 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.8151 - loss: 0.4157 - precision_2: 0.9959 - recall_2: 0.6925 - top_2_categorical_accuracy: 0.8887 - val_accuracy: 0.8658 - val_loss: 0.3793 - val_precision_2: 0.9968 - val_recall_2: 0.6957 - val_top_2_categorical_accuracy: 0.8747 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8689 - loss: 0.3185 - precision_2: 0.9996 - recall_2: 0.7633 - top_2_categorical_accuracy: 0.9168 - val_accuracy: 0.8725 - val_loss: 0.3208 - val_precision_2: 0.9971 - val_recall_2: 0.7606 - val_top_2_categorical_accuracy: 0.9553 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.8927 - loss: 0.2542 - precision_2: 0.9963 - recall_2: 0.8078 - top_2_categorical_accuracy: 0.9620 - val_accuracy: 0.9463 - val_loss: 0.2655 - val_precision_2: 0.9972 - val_recall_2: 0.7830 - val_top_2_categorical_accuracy: 0.9754 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9258 - loss: 0.2147 - precision_2: 0.9933 - recall_2: 0.8297 - top_2_categorical_accuracy: 0.9805 - val_accuracy: 0.9642 - val_loss: 0.2215 - val_precision_2: 0.9972 - val_recall_2: 0.7875 - val_top_2_categorical_accuracy: 0.9888 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9374 - loss: 0.1944 - precision_2: 0.9830 - recall_2: 0.8635 - top_2_categorical_accuracy: 0.9785 - val_accuracy: 0.9620 - val_loss: 0.1893 - val_precision_2: 0.9905 - val_recall_2: 0.9351 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.9512 - loss: 0.1739 - precision_2: 0.9679 - recall_2: 0.9156 - top_2_categorical_accuracy: 0.9884 - val_accuracy: 0.9687 - val_loss: 0.1693 - val_precision_2: 0.9862 - val_recall_2: 0.9597 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9728 - loss: 0.1298 - precision_2: 0.9833 - recall_2: 0.9459 - top_2_categorical_accuracy: 0.9935 - val_accuracy: 0.9687 - val_loss: 0.1468 - val_precision_2: 0.9729 - val_recall_2: 0.9642 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9747 - loss: 0.1200 - precision_2: 0.9829 - recall_2: 0.9635 - top_2_categorical_accuracy: 0.9917 - val_accuracy: 0.9687 - val_loss: 0.1259 - val_precision_2: 0.9709 - val_recall_2: 0.9687 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9714 - loss: 0.1057 - precision_2: 0.9744 - recall_2: 0.9670 - top_2_categorical_accuracy: 0.9903 - val_accuracy: 0.9754 - val_loss: 0.1117 - val_precision_2: 0.9775 - val_recall_2: 0.9709 - val_top_2_categorical_accuracy: 0.9911 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.9734 - loss: 0.0909 - precision_2: 0.9754 - recall_2: 0.9715 - top_2_categorical_accuracy: 0.9921 - val_accuracy: 0.9732 - val_loss: 0.1014 - val_precision_2: 0.9819 - val_recall_2: 0.9709 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9850 - loss: 0.0757 - precision_2: 0.9860 - recall_2: 0.9789 - top_2_categorical_accuracy: 0.9933 - val_accuracy: 0.9732 - val_loss: 0.0878 - val_precision_2: 0.9753 - val_recall_2: 0.9732 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9699 - loss: 0.1070 - precision_2: 0.9719 - recall_2: 0.9665 - top_2_categorical_accuracy: 0.9915 - val_accuracy: 0.9843 - val_loss: 0.0816 - val_precision_2: 0.9888 - val_recall_2: 0.9843 - val_top_2_categorical_accuracy: 0.9911 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 148s 15s/step - accuracy: 0.9777 - loss: 0.0841 - precision_2: 0.9803 - recall_2: 0.9777 - top_2_categorical_accuracy: 0.9900 - val_accuracy: 0.9888 - val_loss: 0.0794 - val_precision_2: 0.9932 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.9889 - loss: 0.0659 - precision_2: 0.9897 - recall_2: 0.9856 - top_2_categorical_accuracy: 0.9948 - val_accuracy: 0.9866 - val_loss: 0.0713 - val_precision_2: 0.9888 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.9889 - loss: 0.0591 - precision_2: 0.9893 - recall_2: 0.9883 - top_2_categorical_accuracy: 0.9963 - val_accuracy: 0.9866 - val_loss: 0.0689 - val_precision_2: 0.9910 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.9863 - loss: 0.0668 - precision_2: 0.9865 - recall_2: 0.9860 - top_2_categorical_accuracy: 0.9899 - val_accuracy: 0.9866 - val_loss: 0.0725 - val_precision_2: 0.9910 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.9864 - loss: 0.0559 - precision_2: 0.9864 - recall_2: 0.9851 - top_2_categorical_accuracy: 0.9938 - val_accuracy: 0.9911 - val_loss: 0.0748 - val_precision_2: 0.9933 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 790ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 710ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75/_win60_overlap75:
# Training Time: 0:46:47.040487
# Validation Accuracy: 0.9865771812080537
# Test Accuracy: 0.9892665474060823
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.93      1.00      0.96        53
#         video       0.99      0.99      0.99        87
# file transfer       1.00      0.99      0.99       245
#          chat       1.00      0.97      0.98        62
#
#      accuracy                           0.99       447
#     macro avg       0.98      0.99      0.98       447
#  weighted avg       0.99      0.99      0.99       447
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.93      1.00      0.96        68
#         video       1.00      0.98      0.99       115
# file transfer       1.00      1.00      1.00       309
#          chat       0.98      0.96      0.97        67
#
#      accuracy                           0.99       559
#     macro avg       0.98      0.98      0.98       559
#  weighted avg       0.99      0.99      0.99       559
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win30 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win30
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 151s 14s/step - accuracy: 0.4919 - loss: 1.2933 - precision_3: 0.5004 - recall_3: 0.0360 - top_2_categorical_accuracy: 0.6725 - val_accuracy: 0.5806 - val_loss: 0.7951 - val_precision_3: 0.8780 - val_recall_3: 0.4977 - val_top_2_categorical_accuracy: 0.7788 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 134s 14s/step - accuracy: 0.5565 - loss: 0.7715 - precision_3: 0.8934 - recall_3: 0.5371 - top_2_categorical_accuracy: 0.7289 - val_accuracy: 0.5806 - val_loss: 0.6061 - val_precision_3: 1.0000 - val_recall_3: 0.5806 - val_top_2_categorical_accuracy: 0.7788 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.6082 - loss: 0.6594 - precision_3: 0.9973 - recall_3: 0.5320 - top_2_categorical_accuracy: 0.7529 - val_accuracy: 0.7788 - val_loss: 0.5341 - val_precision_3: 1.0000 - val_recall_3: 0.6083 - val_top_2_categorical_accuracy: 0.7788 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 133s 13s/step - accuracy: 0.7477 - loss: 0.5375 - precision_3: 0.9923 - recall_3: 0.6140 - top_2_categorical_accuracy: 0.8190 - val_accuracy: 0.7788 - val_loss: 0.4159 - val_precision_3: 1.0000 - val_recall_3: 0.6959 - val_top_2_categorical_accuracy: 0.8940 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.7524 - loss: 0.4711 - precision_3: 0.9995 - recall_3: 0.6560 - top_2_categorical_accuracy: 0.8513 - val_accuracy: 0.7788 - val_loss: 0.3828 - val_precision_3: 1.0000 - val_recall_3: 0.7097 - val_top_2_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.7738 - loss: 0.4168 - precision_3: 1.0000 - recall_3: 0.6928 - top_2_categorical_accuracy: 0.8736 - val_accuracy: 0.7788 - val_loss: 0.3479 - val_precision_3: 1.0000 - val_recall_3: 0.7558 - val_top_2_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.7877 - loss: 0.3875 - precision_3: 1.0000 - recall_3: 0.7257 - top_2_categorical_accuracy: 0.8761 - val_accuracy: 0.8894 - val_loss: 0.3161 - val_precision_3: 1.0000 - val_recall_3: 0.7604 - val_top_2_categorical_accuracy: 0.8986 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8434 - loss: 0.3442 - precision_3: 1.0000 - recall_3: 0.7350 - top_2_categorical_accuracy: 0.9266 - val_accuracy: 0.8940 - val_loss: 0.2880 - val_precision_3: 1.0000 - val_recall_3: 0.7604 - val_top_2_categorical_accuracy: 0.9908 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8374 - loss: 0.3299 - precision_3: 1.0000 - recall_3: 0.7257 - top_2_categorical_accuracy: 0.9593 - val_accuracy: 0.8940 - val_loss: 0.2615 - val_precision_3: 1.0000 - val_recall_3: 0.7650 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8609 - loss: 0.2873 - precision_3: 0.9956 - recall_3: 0.7412 - top_2_categorical_accuracy: 0.9758 - val_accuracy: 0.9032 - val_loss: 0.2363 - val_precision_3: 1.0000 - val_recall_3: 0.7650 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8443 - loss: 0.2792 - precision_3: 0.9835 - recall_3: 0.7387 - top_2_categorical_accuracy: 0.9867 - val_accuracy: 0.8756 - val_loss: 0.2160 - val_precision_3: 1.0000 - val_recall_3: 0.7742 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 134s 14s/step - accuracy: 0.8558 - loss: 0.2561 - precision_3: 0.9291 - recall_3: 0.7858 - top_2_categorical_accuracy: 0.9865 - val_accuracy: 0.8756 - val_loss: 0.2005 - val_precision_3: 1.0000 - val_recall_3: 0.7742 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8705 - loss: 0.2602 - precision_3: 0.9098 - recall_3: 0.8147 - top_2_categorical_accuracy: 0.9905 - val_accuracy: 0.8756 - val_loss: 0.1923 - val_precision_3: 1.0000 - val_recall_3: 0.7742 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 133s 13s/step - accuracy: 0.8658 - loss: 0.2410 - precision_3: 0.9124 - recall_3: 0.8129 - top_2_categorical_accuracy: 0.9870 - val_accuracy: 0.9078 - val_loss: 0.1859 - val_precision_3: 1.0000 - val_recall_3: 0.7742 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 134s 13s/step - accuracy: 0.8842 - loss: 0.2184 - precision_3: 0.9123 - recall_3: 0.8507 - top_2_categorical_accuracy: 0.9920 - val_accuracy: 0.9217 - val_loss: 0.1806 - val_precision_3: 1.0000 - val_recall_3: 0.7788 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 134s 13s/step - accuracy: 0.8700 - loss: 0.2305 - precision_3: 0.8942 - recall_3: 0.8402 - top_2_categorical_accuracy: 0.9885 - val_accuracy: 0.9217 - val_loss: 0.1768 - val_precision_3: 1.0000 - val_recall_3: 0.8018 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.8675 - loss: 0.2245 - precision_3: 0.8997 - recall_3: 0.8381 - top_2_categorical_accuracy: 0.9932 - val_accuracy: 0.9309 - val_loss: 0.1728 - val_precision_3: 1.0000 - val_recall_3: 0.8341 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.8865 - loss: 0.2171 - precision_3: 0.9153 - recall_3: 0.8643 - top_2_categorical_accuracy: 0.9904 - val_accuracy: 0.9493 - val_loss: 0.1686 - val_precision_3: 1.0000 - val_recall_3: 0.8433 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.9060 - loss: 0.1984 - precision_3: 0.9232 - recall_3: 0.8844 - top_2_categorical_accuracy: 0.9936 - val_accuracy: 0.9401 - val_loss: 0.1624 - val_precision_3: 1.0000 - val_recall_3: 0.9124 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.9187 - loss: 0.2006 - precision_3: 0.9329 - recall_3: 0.8959 - top_2_categorical_accuracy: 0.9888 - val_accuracy: 0.9309 - val_loss: 0.1561 - val_precision_3: 0.9479 - val_recall_3: 0.9217 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 723ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 787ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win30/_win30:
# Training Time: 0:45:15.923399
# Validation Accuracy: 0.9308755760368663
# Test Accuracy: 0.915129151291513
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.59      1.00      0.75        22
#         video       1.00      0.98      0.99        43
# file transfer       1.00      1.00      1.00       126
#          chat       1.00      0.46      0.63        26
#
#      accuracy                           0.93       217
#     macro avg       0.90      0.86      0.84       217
#  weighted avg       0.96      0.93      0.93       217
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.55      1.00      0.71        27
#         video       1.00      0.97      0.98        59
# file transfer       0.99      0.99      0.99       154
#          chat       1.00      0.39      0.56        31
#
#      accuracy                           0.92       271
#     macro avg       0.89      0.84      0.81       271
#  weighted avg       0.95      0.92      0.91       271
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win10 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win10
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 149s 15s/step - accuracy: 0.4699 - loss: 1.3537 - precision_4: 0.1818 - recall_4: 4.2614e-04 - top_2_categorical_accuracy: 0.6858 - val_accuracy: 0.6476 - val_loss: 1.0970 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_top_2_categorical_accuracy: 0.8499 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.5890 - loss: 0.9748 - precision_4: 0.8618 - recall_4: 0.3469 - top_2_categorical_accuracy: 0.7692 - val_accuracy: 0.6476 - val_loss: 0.6030 - val_precision_4: 0.8817 - val_recall_4: 0.6408 - val_top_2_categorical_accuracy: 0.8499 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.5992 - loss: 0.6778 - precision_4: 0.8893 - recall_4: 0.5905 - top_2_categorical_accuracy: 0.8025 - val_accuracy: 0.6476 - val_loss: 0.5252 - val_precision_4: 0.9974 - val_recall_4: 0.6408 - val_top_2_categorical_accuracy: 0.8499 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.6111 - loss: 0.6050 - precision_4: 0.9915 - recall_4: 0.5886 - top_2_categorical_accuracy: 0.8009 - val_accuracy: 0.7605 - val_loss: 0.4867 - val_precision_4: 1.0000 - val_recall_4: 0.6408 - val_top_2_categorical_accuracy: 0.8499 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.7266 - loss: 0.5593 - precision_4: 0.9904 - recall_4: 0.5919 - top_2_categorical_accuracy: 0.8057 - val_accuracy: 0.8482 - val_loss: 0.4276 - val_precision_4: 1.0000 - val_recall_4: 0.6813 - val_top_2_categorical_accuracy: 0.9207 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.7876 - loss: 0.4723 - precision_4: 0.9964 - recall_4: 0.6643 - top_2_categorical_accuracy: 0.8950 - val_accuracy: 0.8482 - val_loss: 0.3398 - val_precision_4: 1.0000 - val_recall_4: 0.7487 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.7918 - loss: 0.3967 - precision_4: 0.9993 - recall_4: 0.7089 - top_2_categorical_accuracy: 0.9286 - val_accuracy: 0.8482 - val_loss: 0.3049 - val_precision_4: 1.0000 - val_recall_4: 0.7605 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8169 - loss: 0.3359 - precision_4: 0.9989 - recall_4: 0.7541 - top_2_categorical_accuracy: 0.9459 - val_accuracy: 0.8482 - val_loss: 0.2791 - val_precision_4: 1.0000 - val_recall_4: 0.7993 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8318 - loss: 0.3329 - precision_4: 1.0000 - recall_4: 0.7618 - top_2_categorical_accuracy: 0.9300 - val_accuracy: 0.9359 - val_loss: 0.2507 - val_precision_4: 1.0000 - val_recall_4: 0.8280 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.8793 - loss: 0.3010 - precision_4: 0.9973 - recall_4: 0.7819 - top_2_categorical_accuracy: 0.9359 - val_accuracy: 0.9393 - val_loss: 0.2246 - val_precision_4: 1.0000 - val_recall_4: 0.8381 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.9367 - loss: 0.2443 - precision_4: 0.9995 - recall_4: 0.8002 - top_2_categorical_accuracy: 0.9563 - val_accuracy: 0.9393 - val_loss: 0.2002 - val_precision_4: 1.0000 - val_recall_4: 0.8398 - val_top_2_categorical_accuracy: 0.9427 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.9366 - loss: 0.2225 - precision_4: 0.9764 - recall_4: 0.8368 - top_2_categorical_accuracy: 0.9583 - val_accuracy: 0.9393 - val_loss: 0.1808 - val_precision_4: 1.0000 - val_recall_4: 0.8398 - val_top_2_categorical_accuracy: 0.9815 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.9267 - loss: 0.2140 - precision_4: 0.9630 - recall_4: 0.8795 - top_2_categorical_accuracy: 0.9631 - val_accuracy: 0.9393 - val_loss: 0.1637 - val_precision_4: 0.9392 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.9293 - loss: 0.1945 - precision_4: 0.9461 - recall_4: 0.9049 - top_2_categorical_accuracy: 0.9728 - val_accuracy: 0.9393 - val_loss: 0.1500 - val_precision_4: 0.9424 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.9367 - loss: 0.1880 - precision_4: 0.9506 - recall_4: 0.9085 - top_2_categorical_accuracy: 0.9877 - val_accuracy: 0.9393 - val_loss: 0.1398 - val_precision_4: 0.9472 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 15s/step - accuracy: 0.9290 - loss: 0.1726 - precision_4: 0.9487 - recall_4: 0.9005 - top_2_categorical_accuracy: 0.9930 - val_accuracy: 0.9393 - val_loss: 0.1312 - val_precision_4: 0.9456 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 146s 15s/step - accuracy: 0.9388 - loss: 0.1630 - precision_4: 0.9592 - recall_4: 0.9113 - top_2_categorical_accuracy: 0.9911 - val_accuracy: 0.9410 - val_loss: 0.1248 - val_precision_4: 0.9504 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.9323 - loss: 0.1710 - precision_4: 0.9617 - recall_4: 0.9087 - top_2_categorical_accuracy: 0.9931 - val_accuracy: 0.9427 - val_loss: 0.1168 - val_precision_4: 0.9504 - val_recall_4: 0.9376 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 15s/step - accuracy: 0.9509 - loss: 0.1420 - precision_4: 0.9685 - recall_4: 0.9332 - top_2_categorical_accuracy: 0.9899 - val_accuracy: 0.9798 - val_loss: 0.1100 - val_precision_4: 0.9893 - val_recall_4: 0.9393 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.9621 - loss: 0.1274 - precision_4: 0.9773 - recall_4: 0.9399 - top_2_categorical_accuracy: 0.9922 - val_accuracy: 0.9460 - val_loss: 0.1043 - val_precision_4: 0.9459 - val_recall_4: 0.9427 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 782ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 723ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win10/_win10:
# Training Time: 0:47:47.061780
# Validation Accuracy: 0.9460370994940978
# Test Accuracy: 0.9311740890688259
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       1.00      0.12      0.22        33
#         video       1.00      0.98      0.99       120
# file transfer       1.00      1.00      1.00       384
#          chat       0.64      1.00      0.78        56
#
#      accuracy                           0.95       593
#     macro avg       0.91      0.78      0.75       593
#  weighted avg       0.97      0.95      0.93       593
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       1.00      0.08      0.15        51
#         video       1.00      0.99      0.99       164
# file transfer       1.00      1.00      1.00       440
#          chat       0.63      1.00      0.77        86
#
#      accuracy                           0.93       741
#     macro avg       0.91      0.77      0.73       741
#  weighted avg       0.96      0.93      0.91       741
#
# --------------------------------------------------------------------------------
