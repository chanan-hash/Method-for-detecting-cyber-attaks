# %% [markdown]
# # FlowPic CNN-Model
# ### This notebook run the non-vpn datas in weighted-class with CNN-Model

# %% [markdown]
# ~~~~

# %% [markdown]
#  ~~~~
#  Tests-results:
#  ~~~~
# ##### win-60: 0.978%
# ##### win-60 25% overlap: 0.989%
# ##### win-60 75% overlap: 0.992%
# ##### win-30: 0.981%
# ##### win-10: 0.994%

# %% [markdown]
# ~~~~~

# %% [markdown]
# ~~~~
# cnn-model parameters:
# ~~~~
# ###### 1. Conv_layer= (10, kernel=(10, 10),strides= 5)
# ###### 2. MaxPooling2D = (2, 2)
# ###### 3. Conv_layer= (20, kernel=(10, 10),strides= 5)
# ###### 4. Dropout = 0.25
# ###### 5. MaxPooling2D = (2, 2)
# ###### 6. Flatten
# ###### 7. Dense 64
# ###### 8. Dropout = 0.5
# ###### 9. Output Dense = num_classes

# %% [markdown]
# ~~~~

# %% [markdown]
# #### Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import top_k_categorical_accuracy, Precision, Recall
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import time
from datetime import timedelta
import os

# %% [markdown]
# #### functions

# %%
class CNNDatasetEvaluator:
    def __init__(self, height=1500, width=1500, channels=1):
        """
        Initialize the evaluator with default image dimensions
        
        Parameters:
        - height: Image height
        - width: Image width
        - channels: Number of image channels
        """
        self.height = height
        self.width = width
        self.channels = channels
        self.input_shape = (self.channels, self.height, self.width)
        
        # Default model parameters
        self._conv_layers = [(10, (10, 10), 5), (20, (10, 10), 5)]  # Convolutional layers
        self._dropout_rates = [0.25, 0.5]  # Dropout rates
        self._dense_layers = [64]  # Dense layers

    def compute_class_weights(self, y_train):
        """
        Compute class weights for imbalanced datasets.
        
        Parameters:
        - y_train: Training labels (integer format, not one-hot encoded)
        
        Returns:
        - class_weights: Dictionary of class weights
        """
        # Convert one-hot encoded labels to integer format if necessary
        if len(y_train.shape) > 1 and y_train.shape[1] > 1:
            y_train = np.argmax(y_train, axis=1)
        
        classes = np.unique(y_train)
        class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
        return dict(zip(classes, class_weights))
    
    def top_2_categorical_accuracy(self, y_true, y_pred):
        """Custom top-2 categorical accuracy metric"""
        return top_k_categorical_accuracy(y_true, y_pred, k=2)
    
    def build_model(self, num_classes):
        """
        Build CNN model with flexible architecture
        
        Parameters:
        - num_classes: Number of output classes
        """
        model = Sequential()
        
        # First convolutional layer
        model.add(Conv2D(self._conv_layers[0][0], 
                         kernel_size=self._conv_layers[0][1], 
                         strides=self._conv_layers[0][2], 
                         padding="same", 
                         data_format='channels_last', 
                         input_shape=self.input_shape))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2), padding="same", data_format='channels_last'))
        
        # Additional convolutional layers
        for filters, kernel_size, stride in self._conv_layers[1:]:
            model.add(Conv2D(filters, 
                             kernel_size=kernel_size, 
                             strides=stride, 
                             padding="same", 
                             data_format='channels_last'))
            model.add(Activation('relu'))
            model.add(Dropout(self._dropout_rates[0]))
            model.add(MaxPooling2D(pool_size=(2, 2), padding="same", data_format='channels_last'))
        
        # Flatten and dense layers
        model.add(Flatten())
        for neurons in self._dense_layers:
            model.add(Dense(neurons, activation='relu'))
            model.add(Dropout(self._dropout_rates[1]))
        
        # Output layer
        model.add(Dense(num_classes, activation='softmax'))
        
        return model
    
    def prepare_data(self, X, y, num_classes):
        """
        Prepare data for training
        
        Parameters:
        - X: Input features
        - y: Input labels
        - num_classes: Number of classes
        
        Returns:
        - Processed X and one-hot encoded y
        """
        # Expand dimensions if needed
        if len(X.shape) == 3:
            X = np.expand_dims(X, axis=1)
        elif len(X.shape) != 4:
            raise ValueError(f"Input data must be 3D or 4D, but got shape {X.shape}")
        
        # One-hot encode labels
        y_categorical = to_categorical(y, num_classes)
        
        return X, y_categorical
    
    def train_and_evaluate(self, X_train, y_train, X_val, y_val, X_test, y_test, 
                       class_names=None, 
                       batch_size=128, 
                       epochs=20, 
                       samples_per_epoch=10,
                       use_class_weights=False):
        """
        Train and evaluate the model on given datasets
        
        Parameters:
        - X_train, y_train: Training data
        - X_val, y_val: Validation data
        - X_test, y_test: Test data
        - class_names: Optional list of class names
        - batch_size: Training batch size
        - epochs: Number of training epochs
        - samples_per_epoch: Samples per epoch for generator
        - use_class_weights: Whether to compute and use class weights for imbalanced datasets
        
        Returns:
        - Dictionary with training results
        """
        # Determine number of classes
        num_classes = len(np.unique(y_train))
        
        # Prepare data
        X_train, y_train = self.prepare_data(X_train, y_train, num_classes)
        X_val, y_val = self.prepare_data(X_val, y_val, num_classes)
        X_test, y_test = self.prepare_data(X_test, y_test, num_classes)
        
        # Compute class weights if requested
        class_weights = None
        if use_class_weights:
            y_train_classes = np.argmax(y_train, axis=1) if len(y_train.shape) > 1 else y_train
            class_weights = self.compute_class_weights(y_train_classes)
        
        # Build model
        model = self.build_model(num_classes)
        
        # Compile model
        model.compile(
            loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy', self.top_2_categorical_accuracy, Precision(), Recall()]
        )
        
        # Callbacks
        callbacks = [
            EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=3,
                min_lr=1e-6
            ),
            TensorBoard(log_dir='./Graph', histogram_freq=1, write_graph=True, write_images=True)
        ]
        
        # Simple generator
        def generator(features, labels, batch_size):
            index = 0
            while True:
                index += batch_size
                if index >= len(features):
                    batch_features = np.append(features[index - batch_size:len(features)], 
                                               features[0:index - len(features)], axis=0)
                    batch_labels = np.append(labels[index - batch_size:len(features)], 
                                             labels[0:index - len(features)], axis=0)
                    index -= len(features)
                    yield batch_features, batch_labels
                else:
                    yield features[index - batch_size:index], labels[index - batch_size:index]

        def weighted_generator(features, labels, batch_size, class_weights):
            index = 0
            num_samples = len(features)
            while True:
                index += batch_size
                if index >= num_samples:
                    batch_features = np.append(features[index - batch_size:num_samples], 
                                               features[0:index - num_samples], axis=0)
                    batch_labels = np.append(labels[index - batch_size:num_samples], 
                                             labels[0:index - num_samples], axis=0)
                    index -= num_samples
                else:
                    batch_features = features[index - batch_size:index]
                    batch_labels = labels[index - batch_size:index]
                
                # Compute sample weights based on class weights
                sample_weights = np.array([class_weights[np.argmax(label)] for label in batch_labels])
                
                yield batch_features, batch_labels, sample_weights
        
        # Train model
        start_time = time.time()
        if use_class_weights:
            # Use the weighted generator
            train_gen = weighted_generator(X_train, y_train, batch_size, class_weights)
            history = model.fit(
                train_gen,
                epochs=epochs,
                steps_per_epoch=samples_per_epoch,
                verbose=1,
                callbacks=callbacks,
                validation_data=(X_val, y_val)
            )
        else:
        # Use the original generator
            train_gen = generator(X_train, y_train, batch_size)
            history = model.fit(
                train_gen,
                epochs=epochs,
                steps_per_epoch=samples_per_epoch,
                verbose=1,
                callbacks=callbacks,
                validation_data=(X_val, y_val)
            )
        
        # Calculate training time
        training_time = time.time() - start_time
        
        # Predictions
        y_val_pred = model.predict(X_val)
        y_test_pred = model.predict(X_test)
        
        y_val_pred_classes = np.argmax(y_val_pred, axis=1)
        y_test_pred_classes = np.argmax(y_test_pred, axis=1)
        
        # Convert y_test and y_val from one-hot encoded to integer labels if necessary
        y_val_classes = np.argmax(y_val, axis=1) if len(y_val.shape) > 1 else y_val
        y_test_classes = np.argmax(y_test, axis=1) if len(y_test.shape) > 1 else y_test
        
        # Results
        results = {
            'training_time': timedelta(seconds=training_time),
            'val_classification_report': classification_report(
                y_val_classes, 
                y_val_pred_classes, 
                target_names=class_names
            ),
            'test_classification_report': classification_report(
                y_test_classes, 
                y_test_pred_classes, 
                target_names=class_names
            ),
            'val_accuracy': np.mean(y_val_pred_classes == y_val_classes),
            'test_accuracy': np.mean(y_test_pred_classes == y_test_classes),
            'history': history.history,
            'test_predictions': y_test_pred
        }
        
        return results
    
    # Getter and Setter methods for model parameters
    def get_conv_layers(self):
        """Get the convolutional layers configuration"""
        return self._conv_layers
    
    def set_conv_layers(self, conv_layers):
        """Set the convolutional layers configuration"""
        self._conv_layers = conv_layers
    
    def get_dropout_rates(self):
        """Get the dropout rates"""
        return self._dropout_rates
    
    def set_dropout_rates(self, dropout_rates):
        """Set the dropout rates"""
        self._dropout_rates = dropout_rates
    
    def get_dense_layers(self):
        """Get the dense layers configuration"""
        return self._dense_layers
    
    def set_dense_layers(self, dense_layers):
        """Set the dense layers configuration"""
        self._dense_layers = dense_layers

# %%
def load_data(base_dir, dataset_prefix):
    """
    Load dataset files from a specified directory based on a common prefix.
    
    Parameters:
    - base_dir: Directory where the dataset files are stored
    - dataset_prefix: Common prefix for the dataset files (e.g., 'reg_X_train')
    
    Returns:
    - X_train, y_train, X_val, y_val, X_test, y_test
    """
    try:
        X_train = np.load(f"{base_dir}/reg_X_train{dataset_prefix}.npy")
        y_train = np.load(f"{base_dir}/reg_y_train{dataset_prefix}.npy")
        X_val = np.load(f"{base_dir}/reg_X_val{dataset_prefix}.npy")
        y_val = np.load(f"{base_dir}/reg_y_val{dataset_prefix}.npy")
        X_test = np.load(f"{base_dir}/reg_X_test{dataset_prefix}.npy")
        y_test = np.load(f"{base_dir}/reg_y_test{dataset_prefix}.npy")
    except FileNotFoundError as e:
        print(f"Error loading dataset: {e}")
        return None, None, None, None, None, None
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def plot_confusion_matrix(y_true, y_pred, class_names):
    """
    Plot a confusion matrix.
    
    Parameters:
    - y_true: True labels
    - y_pred: Predicted labels
    - class_names: List of class names
    """
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
def plot_learning_curves(history):
    """
    Plot learning curves (accuracy and loss) for training and validation.
    
    Parameters:
    - history: Training history returned by model.fit()
    """
    # Plot accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Training Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Training Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.show()

# %%
def evaluate_datasets(dataset_info,
                      height,
                      width,
                      channels,
                      class_names,
                      conv_layers=[(10, (10, 10), 5), (20, (10, 10), 5)],
                      dropout_rates=[0.25, 0.5],
                      dense_layers=[64],
                      batch_size=128,
                      epochs=20,
                      samples_per_epoch=10,
                      use_class_weights=False  # Enable class weights
                     ):

    """
    Evaluate the model on multiple datasets from different directories.
    
    Parameters:
    - dataset_info: List of tuples containing (base_dir, dataset_prefix)
    - height, width, channels: Image dimensions
    - class_names: List of class names for classification report
    - conv_layers,dropout_rates,dense_layers: model parameters
    - batch_size, epochs, samples_per_epoch: Training parameters
    - use_class_weights: give weights to classes with less samples
    """
    results = {}
    
    for base_dir, prefix in dataset_info:
        print(f"Evaluating dataset: {prefix} from directory: {base_dir}")
        
        # Load data
        X_train, y_train, X_val, y_val, X_test, y_test = load_data(base_dir, prefix)
        
        # Initialize evaluator
        evaluator = CNNDatasetEvaluator(height=height, width=width, channels=channels)

        # Update parameters
        evaluator.set_conv_layers(conv_layers)
        evaluator.set_dropout_rates(dropout_rates)
        evaluator.set_dense_layers(dense_layers)

        # Verify updated parameters
        print("Conv Layers:", evaluator.get_conv_layers())
        print("Dropout Rates:", evaluator.get_dropout_rates())
        print("Dense Layers:", evaluator.get_dense_layers())

        # Train and evaluate
        result = evaluator.train_and_evaluate(
            X_train, y_train, X_val, y_val, X_test, y_test,
            class_names=class_names,
            batch_size=batch_size,
            epochs=epochs,
            samples_per_epoch=samples_per_epoch,
            use_class_weights=use_class_weights
        )
        
        # Store results
        results[f"{base_dir}/{prefix}"] = result
        
        # Print results
        print(f"Results for {base_dir}/{prefix}:")
        print(f"Training Time: {result['training_time']}")
        print(f"Validation Accuracy: {result['val_accuracy']}")
        print(f"Test Accuracy: {result['test_accuracy']}")
        print("Validation Classification Report:")
        print(result['val_classification_report'])
        print("Test Classification Report:")
        print(result['test_classification_report'])
        print("-" * 80)

        #plot confusion matrix
        if len(y_test.shape) == 1:
            y_test_true = y_test  # Already integer labels
        else:
            y_test_true = np.argmax(y_test, axis=1)  # Convert one-hot to integer labels

        if len(result['test_predictions'].shape) == 1:
            y_test_pred = result['test_predictions']  # Already integer labels
        else:
            y_test_pred = np.argmax(result['test_predictions'], axis=1)  # Convert one-hot to integer labels

        plot_confusion_matrix(y_true=y_test_true, y_pred=y_test_pred, class_names=class_names)

        #plot learning curves
        history = result['history']
        plot_learning_curves(history)
    
    return results

# %% [markdown]
# #### parameters preper

# %%
# List of datasets with their directories and prefixes
dataset_info = [
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy', ''),  # Dataset 1 in directory 'path/to/dataset1'
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy', '_win60_overlap25'),  # Dataset 2 in directory 'path/to/dataset2'
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75', '_win60_overlap75'),
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win30', '_win30'),
    ('/kaggle/input/vpn-non-vpn-iscx-2016-npy/win10' , '_win10')
]

# %%
batch_size = 128 #128
samples_per_epoch = 10
num_classes = 4
epochs = 20 #20
class_names = ["voip", "video", "file transfer", "chat"]

# input hist dimensions
height, width = 1500, 1500
channels = 1
input_shape = (1, height, width)

# %% [markdown]
# ~~~~~~~
#  fit the model on:
# ~~~~~~~
# ###### 1. win60
# ###### 2. win60 overlap 25%
# ###### 3. win60 overlap 75%
# ###### 4. win 30
# ###### 5. win 10

# %%
# Evaluate datasets
results_1 = evaluate_datasets(
    dataset_info=dataset_info,
    height=height,
    width=width,
    channels=channels,
    class_names=class_names,
    conv_layers= [(10, (10, 10), 5), (20, (10, 10), 5)],
    dropout_rates=[0.25, 0.5],
    dense_layers=[64],
    batch_size=batch_size,
    epochs=epochs,
    samples_per_epoch=samples_per_epoch,
    use_class_weights=True
)
# Out:
# Evaluating dataset:  from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 18s/step - accuracy: 0.4400 - loss: 1.3541 - precision: 0.4545 - recall: 0.0075 - top_2_categorical_accuracy: 0.6855 - val_accuracy: 0.6241 - val_loss: 1.0803 - val_precision: 1.0000 - val_recall: 0.0922 - val_top_2_categorical_accuracy: 0.8582 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 18s/step - accuracy: 0.7609 - loss: 1.0359 - precision: 0.9816 - recall: 0.3686 - top_2_categorical_accuracy: 0.9138 - val_accuracy: 0.8085 - val_loss: 0.5473 - val_precision: 1.0000 - val_recall: 0.5532 - val_top_2_categorical_accuracy: 0.8582 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.8654 - loss: 0.7426 - precision: 0.9934 - recall: 0.6771 - top_2_categorical_accuracy: 0.9373 - val_accuracy: 0.8085 - val_loss: 0.3855 - val_precision: 1.0000 - val_recall: 0.7376 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.8852 - loss: 0.5901 - precision: 1.0000 - recall: 0.7765 - top_2_categorical_accuracy: 0.9541 - val_accuracy: 0.8227 - val_loss: 0.3211 - val_precision: 1.0000 - val_recall: 0.7447 - val_top_2_categorical_accuracy: 0.9574 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.8926 - loss: 0.4949 - precision: 0.9964 - recall: 0.8056 - top_2_categorical_accuracy: 0.9768 - val_accuracy: 0.9433 - val_loss: 0.2801 - val_precision: 1.0000 - val_recall: 0.7447 - val_top_2_categorical_accuracy: 0.9574 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 184s 19s/step - accuracy: 0.9199 - loss: 0.3998 - precision: 0.9759 - recall: 0.8408 - top_2_categorical_accuracy: 0.9804 - val_accuracy: 0.9220 - val_loss: 0.2509 - val_precision: 0.9907 - val_recall: 0.7518 - val_top_2_categorical_accuracy: 0.9574 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9292 - loss: 0.3399 - precision: 0.9591 - recall: 0.8831 - top_2_categorical_accuracy: 0.9824 - val_accuracy: 0.9433 - val_loss: 0.2289 - val_precision: 0.9630 - val_recall: 0.9220 - val_top_2_categorical_accuracy: 0.9574 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9366 - loss: 0.2927 - precision: 0.9489 - recall: 0.9184 - top_2_categorical_accuracy: 0.9793 - val_accuracy: 0.9504 - val_loss: 0.2059 - val_precision: 0.9568 - val_recall: 0.9433 - val_top_2_categorical_accuracy: 0.9716 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 187s 19s/step - accuracy: 0.9599 - loss: 0.2404 - precision: 0.9719 - recall: 0.9505 - top_2_categorical_accuracy: 0.9849 - val_accuracy: 0.9504 - val_loss: 0.1784 - val_precision: 0.9504 - val_recall: 0.9504 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9672 - loss: 0.1826 - precision: 0.9681 - recall: 0.9634 - top_2_categorical_accuracy: 0.9882 - val_accuracy: 0.9574 - val_loss: 0.1575 - val_precision: 0.9571 - val_recall: 0.9504 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9736 - loss: 0.1376 - precision: 0.9758 - recall: 0.9726 - top_2_categorical_accuracy: 0.9894 - val_accuracy: 0.9574 - val_loss: 0.1365 - val_precision: 0.9643 - val_recall: 0.9574 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9762 - loss: 0.1213 - precision: 0.9762 - recall: 0.9760 - top_2_categorical_accuracy: 0.9902 - val_accuracy: 0.9574 - val_loss: 0.1302 - val_precision: 0.9574 - val_recall: 0.9574 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 185s 19s/step - accuracy: 0.9819 - loss: 0.0832 - precision: 0.9827 - recall: 0.9817 - top_2_categorical_accuracy: 0.9911 - val_accuracy: 0.9574 - val_loss: 0.1239 - val_precision: 0.9574 - val_recall: 0.9574 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9855 - loss: 0.0635 - precision: 0.9855 - recall: 0.9845 - top_2_categorical_accuracy: 0.9944 - val_accuracy: 0.9716 - val_loss: 0.1161 - val_precision: 0.9716 - val_recall: 0.9716 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9910 - loss: 0.0590 - precision: 0.9914 - recall: 0.9910 - top_2_categorical_accuracy: 0.9922 - val_accuracy: 0.9574 - val_loss: 0.1227 - val_precision: 0.9574 - val_recall: 0.9574 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9866 - loss: 0.0559 - precision: 0.9885 - recall: 0.9866 - top_2_categorical_accuracy: 0.9918 - val_accuracy: 0.9645 - val_loss: 0.1212 - val_precision: 0.9714 - val_recall: 0.9645 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9894 - loss: 0.0489 - precision: 0.9917 - recall: 0.9883 - top_2_categorical_accuracy: 0.9931 - val_accuracy: 0.9645 - val_loss: 0.1175 - val_precision: 0.9645 - val_recall: 0.9645 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9894 - loss: 0.0402 - precision: 0.9894 - recall: 0.9888 - top_2_categorical_accuracy: 0.9926 - val_accuracy: 0.9645 - val_loss: 0.1179 - val_precision: 0.9645 - val_recall: 0.9645 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 2.0000e-04
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9901 - loss: 0.0432 - precision: 0.9906 - recall: 0.9901 - top_2_categorical_accuracy: 0.9926 - val_accuracy: 0.9645 - val_loss: 0.1174 - val_precision: 0.9645 - val_recall: 0.9645 - val_top_2_categorical_accuracy: 0.9787 - learning_rate: 2.0000e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 711ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/:
# Training Time: 0:56:43.206097
# Validation Accuracy: 0.9716312056737588
# Test Accuracy: 0.9787234042553191
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.90      1.00      0.95        19
#         video       1.00      0.89      0.94        27
# file transfer       0.99      1.00      0.99        80
#          chat       0.93      0.93      0.93        15
#
#      accuracy                           0.97       141
#     macro avg       0.96      0.96      0.95       141
#  weighted avg       0.97      0.97      0.97       141
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.88      1.00      0.94        23
#         video       1.00      0.97      0.98        30
# file transfer       1.00      0.99      0.99        72
#          chat       1.00      0.94      0.97        16
#
#      accuracy                           0.98       141
#     macro avg       0.97      0.97      0.97       141
#  weighted avg       0.98      0.98      0.98       141
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win60_overlap25 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 182s 18s/step - accuracy: 0.4208 - loss: 1.3451 - precision_1: 0.4274 - recall_1: 0.0114 - top_2_categorical_accuracy: 0.6282 - val_accuracy: 0.7800 - val_loss: 0.9859 - val_precision_1: 1.0000 - val_recall_1: 0.2933 - val_top_2_categorical_accuracy: 0.8400 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 175s 18s/step - accuracy: 0.7701 - loss: 1.0171 - precision_1: 0.9687 - recall_1: 0.4410 - top_2_categorical_accuracy: 0.9225 - val_accuracy: 0.8400 - val_loss: 0.5707 - val_precision_1: 0.9890 - val_recall_1: 0.6000 - val_top_2_categorical_accuracy: 0.9667 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 176s 18s/step - accuracy: 0.8634 - loss: 0.7844 - precision_1: 0.9936 - recall_1: 0.6948 - top_2_categorical_accuracy: 0.9612 - val_accuracy: 0.9067 - val_loss: 0.4716 - val_precision_1: 0.9804 - val_recall_1: 0.6667 - val_top_2_categorical_accuracy: 0.9667 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 186s 19s/step - accuracy: 0.9037 - loss: 0.6702 - precision_1: 0.9967 - recall_1: 0.7416 - top_2_categorical_accuracy: 0.9827 - val_accuracy: 0.8067 - val_loss: 0.3851 - val_precision_1: 0.9815 - val_recall_1: 0.7067 - val_top_2_categorical_accuracy: 0.9733 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.9005 - loss: 0.5352 - precision_1: 0.9986 - recall_1: 0.7760 - top_2_categorical_accuracy: 0.9863 - val_accuracy: 0.9200 - val_loss: 0.3225 - val_precision_1: 0.9817 - val_recall_1: 0.7133 - val_top_2_categorical_accuracy: 0.9733 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 187s 19s/step - accuracy: 0.9129 - loss: 0.4419 - precision_1: 0.9873 - recall_1: 0.8058 - top_2_categorical_accuracy: 0.9832 - val_accuracy: 0.9200 - val_loss: 0.2711 - val_precision_1: 0.9737 - val_recall_1: 0.7400 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 186s 19s/step - accuracy: 0.9300 - loss: 0.3383 - precision_1: 0.9628 - recall_1: 0.8971 - top_2_categorical_accuracy: 0.9902 - val_accuracy: 0.9333 - val_loss: 0.2467 - val_precision_1: 0.9392 - val_recall_1: 0.9267 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 18s/step - accuracy: 0.9442 - loss: 0.2650 - precision_1: 0.9581 - recall_1: 0.9321 - top_2_categorical_accuracy: 0.9883 - val_accuracy: 0.9333 - val_loss: 0.2160 - val_precision_1: 0.9459 - val_recall_1: 0.9333 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9583 - loss: 0.2211 - precision_1: 0.9698 - recall_1: 0.9517 - top_2_categorical_accuracy: 0.9928 - val_accuracy: 0.9533 - val_loss: 0.1880 - val_precision_1: 0.9527 - val_recall_1: 0.9400 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 187s 19s/step - accuracy: 0.9755 - loss: 0.1478 - precision_1: 0.9766 - recall_1: 0.9664 - top_2_categorical_accuracy: 0.9974 - val_accuracy: 0.9533 - val_loss: 0.1655 - val_precision_1: 0.9597 - val_recall_1: 0.9533 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9786 - loss: 0.1380 - precision_1: 0.9850 - recall_1: 0.9731 - top_2_categorical_accuracy: 0.9963 - val_accuracy: 0.9533 - val_loss: 0.1319 - val_precision_1: 0.9533 - val_recall_1: 0.9533 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9770 - loss: 0.1084 - precision_1: 0.9804 - recall_1: 0.9740 - top_2_categorical_accuracy: 0.9972 - val_accuracy: 0.9533 - val_loss: 0.1207 - val_precision_1: 0.9533 - val_recall_1: 0.9533 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9853 - loss: 0.0955 - precision_1: 0.9863 - recall_1: 0.9846 - top_2_categorical_accuracy: 0.9952 - val_accuracy: 0.9667 - val_loss: 0.1153 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9902 - loss: 0.0631 - precision_1: 0.9905 - recall_1: 0.9902 - top_2_categorical_accuracy: 0.9971 - val_accuracy: 0.9667 - val_loss: 0.1492 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9867 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9922 - loss: 0.0530 - precision_1: 0.9922 - recall_1: 0.9917 - top_2_categorical_accuracy: 0.9984 - val_accuracy: 0.9667 - val_loss: 0.1962 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9927 - loss: 0.0447 - precision_1: 0.9927 - recall_1: 0.9906 - top_2_categorical_accuracy: 0.9978 - val_accuracy: 0.9733 - val_loss: 0.2017 - val_precision_1: 0.9733 - val_recall_1: 0.9733 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9928 - loss: 0.0488 - precision_1: 0.9928 - recall_1: 0.9928 - top_2_categorical_accuracy: 0.9983 - val_accuracy: 0.9733 - val_loss: 0.2014 - val_precision_1: 0.9733 - val_recall_1: 0.9733 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 2.0000e-04
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9914 - loss: 0.0620 - precision_1: 0.9920 - recall_1: 0.9914 - top_2_categorical_accuracy: 0.9970 - val_accuracy: 0.9667 - val_loss: 0.1710 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_top_2_categorical_accuracy: 0.9800 - learning_rate: 2.0000e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 749ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/_win60_overlap25:
# Training Time: 0:53:59.151617
# Validation Accuracy: 0.9666666666666667
# Test Accuracy: 0.9893048128342246
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.85      1.00      0.92        23
#         video       1.00      0.90      0.95        31
# file transfer       0.99      1.00      0.99        76
#          chat       1.00      0.90      0.95        20
#
#      accuracy                           0.97       150
#     macro avg       0.96      0.95      0.95       150
#  weighted avg       0.97      0.97      0.97       150
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.92      1.00      0.96        24
#         video       1.00      0.97      0.99        36
# file transfer       1.00      1.00      1.00       101
#          chat       1.00      0.96      0.98        26
#
#      accuracy                           0.99       187
#     macro avg       0.98      0.98      0.98       187
#  weighted avg       0.99      0.99      0.99       187
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win60_overlap75 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 182s 18s/step - accuracy: 0.2940 - loss: 1.3792 - precision_2: 0.4545 - recall_2: 0.0045 - top_2_categorical_accuracy: 0.4967 - val_accuracy: 0.7763 - val_loss: 1.2117 - val_precision_2: 1.0000 - val_recall_2: 0.0828 - val_top_2_categorical_accuracy: 0.8434 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.7884 - loss: 1.0611 - precision_2: 0.9976 - recall_2: 0.1898 - top_2_categorical_accuracy: 0.8850 - val_accuracy: 0.8367 - val_loss: 0.6331 - val_precision_2: 1.0000 - val_recall_2: 0.5749 - val_top_2_categorical_accuracy: 0.9732 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 18s/step - accuracy: 0.8397 - loss: 0.7373 - precision_2: 1.0000 - recall_2: 0.6318 - top_2_categorical_accuracy: 0.9378 - val_accuracy: 0.8456 - val_loss: 0.3770 - val_precision_2: 0.9970 - val_recall_2: 0.7383 - val_top_2_categorical_accuracy: 0.9709 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 190s 18s/step - accuracy: 0.8549 - loss: 0.5716 - precision_2: 0.9996 - recall_2: 0.7601 - top_2_categorical_accuracy: 0.9730 - val_accuracy: 0.8635 - val_loss: 0.2827 - val_precision_2: 0.9971 - val_recall_2: 0.7696 - val_top_2_categorical_accuracy: 0.9754 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.8887 - loss: 0.4243 - precision_2: 0.9979 - recall_2: 0.8064 - top_2_categorical_accuracy: 0.9772 - val_accuracy: 0.9329 - val_loss: 0.2340 - val_precision_2: 0.9971 - val_recall_2: 0.7808 - val_top_2_categorical_accuracy: 0.9709 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9316 - loss: 0.3292 - precision_2: 0.9721 - recall_2: 0.8765 - top_2_categorical_accuracy: 0.9799 - val_accuracy: 0.9463 - val_loss: 0.1993 - val_precision_2: 0.9878 - val_recall_2: 0.9083 - val_top_2_categorical_accuracy: 0.9732 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 190s 19s/step - accuracy: 0.9414 - loss: 0.2942 - precision_2: 0.9610 - recall_2: 0.9158 - top_2_categorical_accuracy: 0.9826 - val_accuracy: 0.9508 - val_loss: 0.1693 - val_precision_2: 0.9738 - val_recall_2: 0.9150 - val_top_2_categorical_accuracy: 0.9776 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 18s/step - accuracy: 0.9416 - loss: 0.2787 - precision_2: 0.9571 - recall_2: 0.9211 - top_2_categorical_accuracy: 0.9814 - val_accuracy: 0.9776 - val_loss: 0.1361 - val_precision_2: 0.9840 - val_recall_2: 0.9620 - val_top_2_categorical_accuracy: 0.9911 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9570 - loss: 0.2427 - precision_2: 0.9677 - recall_2: 0.9388 - top_2_categorical_accuracy: 0.9841 - val_accuracy: 0.9821 - val_loss: 0.1124 - val_precision_2: 0.9841 - val_recall_2: 0.9709 - val_top_2_categorical_accuracy: 0.9911 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9778 - loss: 0.1627 - precision_2: 0.9817 - recall_2: 0.9717 - top_2_categorical_accuracy: 0.9913 - val_accuracy: 0.9843 - val_loss: 0.0937 - val_precision_2: 0.9887 - val_recall_2: 0.9821 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 184s 19s/step - accuracy: 0.9855 - loss: 0.1333 - precision_2: 0.9889 - recall_2: 0.9812 - top_2_categorical_accuracy: 0.9930 - val_accuracy: 0.9821 - val_loss: 0.0785 - val_precision_2: 0.9843 - val_recall_2: 0.9821 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9728 - loss: 0.1302 - precision_2: 0.9728 - recall_2: 0.9728 - top_2_categorical_accuracy: 0.9875 - val_accuracy: 0.9843 - val_loss: 0.0660 - val_precision_2: 0.9843 - val_recall_2: 0.9843 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9817 - loss: 0.0933 - precision_2: 0.9853 - recall_2: 0.9788 - top_2_categorical_accuracy: 0.9947 - val_accuracy: 0.9866 - val_loss: 0.0618 - val_precision_2: 0.9888 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9887 - loss: 0.0866 - precision_2: 0.9887 - recall_2: 0.9855 - top_2_categorical_accuracy: 0.9936 - val_accuracy: 0.9843 - val_loss: 0.0580 - val_precision_2: 0.9843 - val_recall_2: 0.9843 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9781 - loss: 0.1051 - precision_2: 0.9780 - recall_2: 0.9779 - top_2_categorical_accuracy: 0.9879 - val_accuracy: 0.9866 - val_loss: 0.0537 - val_precision_2: 0.9888 - val_recall_2: 0.9866 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 177s 18s/step - accuracy: 0.9827 - loss: 0.0967 - precision_2: 0.9828 - recall_2: 0.9806 - top_2_categorical_accuracy: 0.9907 - val_accuracy: 0.9888 - val_loss: 0.0557 - val_precision_2: 0.9888 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 178s 18s/step - accuracy: 0.9882 - loss: 0.0577 - precision_2: 0.9908 - recall_2: 0.9873 - top_2_categorical_accuracy: 0.9952 - val_accuracy: 0.9888 - val_loss: 0.0534 - val_precision_2: 0.9888 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9892 - loss: 0.1258 - precision_2: 0.9900 - recall_2: 0.9877 - top_2_categorical_accuracy: 0.9985 - val_accuracy: 0.9888 - val_loss: 0.0604 - val_precision_2: 0.9910 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9978 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9829 - loss: 0.0744 - precision_2: 0.9833 - recall_2: 0.9829 - top_2_categorical_accuracy: 0.9924 - val_accuracy: 0.9888 - val_loss: 0.0601 - val_precision_2: 0.9888 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 18s/step - accuracy: 0.9916 - loss: 0.0500 - precision_2: 0.9927 - recall_2: 0.9886 - top_2_categorical_accuracy: 0.9952 - val_accuracy: 0.9888 - val_loss: 0.0539 - val_precision_2: 0.9888 - val_recall_2: 0.9888 - val_top_2_categorical_accuracy: 0.9955 - learning_rate: 0.0010
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 781ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 795ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win60_overlap75/_win60_overlap75:
# Training Time: 1:00:05.236899
# Validation Accuracy: 0.9888143176733781
# Test Accuracy: 0.9928443649373881
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.95      1.00      0.97        53
#         video       1.00      0.99      0.99        87
# file transfer       1.00      0.99      0.99       245
#          chat       0.98      0.98      0.98        62
#
#      accuracy                           0.99       447
#     macro avg       0.98      0.99      0.99       447
#  weighted avg       0.99      0.99      0.99       447
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.96      1.00      0.98        68
#         video       1.00      0.98      0.99       115
# file transfer       1.00      1.00      1.00       309
#          chat       0.99      0.99      0.99        67
#
#      accuracy                           0.99       559
#     macro avg       0.99      0.99      0.99       559
#  weighted avg       0.99      0.99      0.99       559
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win30 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win30
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 188s 18s/step - accuracy: 0.4453 - loss: 1.3579 - precision_3: 0.2727 - recall_3: 0.0034 - top_2_categorical_accuracy: 0.7097 - val_accuracy: 0.7742 - val_loss: 1.0039 - val_precision_3: 1.0000 - val_recall_3: 0.1797 - val_top_2_categorical_accuracy: 0.9355 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 176s 18s/step - accuracy: 0.7262 - loss: 1.0966 - precision_3: 0.8633 - recall_3: 0.3628 - top_2_categorical_accuracy: 0.9283 - val_accuracy: 0.8756 - val_loss: 0.5143 - val_precision_3: 1.0000 - val_recall_3: 0.6912 - val_top_2_categorical_accuracy: 0.9724 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.8406 - loss: 0.8233 - precision_3: 0.9884 - recall_3: 0.6505 - top_2_categorical_accuracy: 0.9628 - val_accuracy: 0.8756 - val_loss: 0.3337 - val_precision_3: 1.0000 - val_recall_3: 0.7419 - val_top_2_categorical_accuracy: 0.9770 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 173s 17s/step - accuracy: 0.8682 - loss: 0.6134 - precision_3: 0.9981 - recall_3: 0.7226 - top_2_categorical_accuracy: 0.9675 - val_accuracy: 0.8802 - val_loss: 0.2496 - val_precision_3: 1.0000 - val_recall_3: 0.7880 - val_top_2_categorical_accuracy: 0.9816 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 174s 18s/step - accuracy: 0.8662 - loss: 0.5121 - precision_3: 0.9909 - recall_3: 0.7549 - top_2_categorical_accuracy: 0.9781 - val_accuracy: 0.9355 - val_loss: 0.1908 - val_precision_3: 1.0000 - val_recall_3: 0.8295 - val_top_2_categorical_accuracy: 0.9816 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 171s 17s/step - accuracy: 0.8970 - loss: 0.4074 - precision_3: 0.9538 - recall_3: 0.8320 - top_2_categorical_accuracy: 0.9775 - val_accuracy: 0.9401 - val_loss: 0.1573 - val_precision_3: 0.9949 - val_recall_3: 0.8986 - val_top_2_categorical_accuracy: 0.9862 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.9134 - loss: 0.3501 - precision_3: 0.9491 - recall_3: 0.8763 - top_2_categorical_accuracy: 0.9835 - val_accuracy: 0.9447 - val_loss: 0.1382 - val_precision_3: 0.9808 - val_recall_3: 0.9401 - val_top_2_categorical_accuracy: 0.9908 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 176s 18s/step - accuracy: 0.9205 - loss: 0.3120 - precision_3: 0.9441 - recall_3: 0.8976 - top_2_categorical_accuracy: 0.9900 - val_accuracy: 0.9677 - val_loss: 0.1215 - val_precision_3: 0.9808 - val_recall_3: 0.9401 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 171s 17s/step - accuracy: 0.9479 - loss: 0.2885 - precision_3: 0.9670 - recall_3: 0.9207 - top_2_categorical_accuracy: 0.9874 - val_accuracy: 0.9816 - val_loss: 0.1050 - val_precision_3: 0.9813 - val_recall_3: 0.9677 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 171s 17s/step - accuracy: 0.9564 - loss: 0.2426 - precision_3: 0.9682 - recall_3: 0.9388 - top_2_categorical_accuracy: 0.9911 - val_accuracy: 0.9816 - val_loss: 0.0885 - val_precision_3: 0.9816 - val_recall_3: 0.9816 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 173s 17s/step - accuracy: 0.9746 - loss: 0.1928 - precision_3: 0.9820 - recall_3: 0.9673 - top_2_categorical_accuracy: 0.9911 - val_accuracy: 0.9816 - val_loss: 0.0710 - val_precision_3: 0.9816 - val_recall_3: 0.9816 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 170s 17s/step - accuracy: 0.9790 - loss: 0.1760 - precision_3: 0.9796 - recall_3: 0.9759 - top_2_categorical_accuracy: 0.9905 - val_accuracy: 0.9816 - val_loss: 0.0601 - val_precision_3: 0.9816 - val_recall_3: 0.9816 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.9805 - loss: 0.1391 - precision_3: 0.9827 - recall_3: 0.9755 - top_2_categorical_accuracy: 0.9916 - val_accuracy: 0.9862 - val_loss: 0.0497 - val_precision_3: 0.9907 - val_recall_3: 0.9816 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 171s 17s/step - accuracy: 0.9821 - loss: 0.1095 - precision_3: 0.9837 - recall_3: 0.9817 - top_2_categorical_accuracy: 0.9897 - val_accuracy: 0.9908 - val_loss: 0.0437 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 0.9954 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 173s 17s/step - accuracy: 0.9846 - loss: 0.0895 - precision_3: 0.9846 - recall_3: 0.9836 - top_2_categorical_accuracy: 0.9922 - val_accuracy: 0.9862 - val_loss: 0.0401 - val_precision_3: 0.9907 - val_recall_3: 0.9862 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 173s 17s/step - accuracy: 0.9842 - loss: 0.1100 - precision_3: 0.9848 - recall_3: 0.9842 - top_2_categorical_accuracy: 0.9891 - val_accuracy: 0.9908 - val_loss: 0.0348 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 171s 17s/step - accuracy: 0.9866 - loss: 0.0858 - precision_3: 0.9869 - recall_3: 0.9866 - top_2_categorical_accuracy: 0.9944 - val_accuracy: 0.9908 - val_loss: 0.0334 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.9875 - loss: 0.0806 - precision_3: 0.9878 - recall_3: 0.9875 - top_2_categorical_accuracy: 0.9905 - val_accuracy: 0.9908 - val_loss: 0.0294 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 173s 17s/step - accuracy: 0.9918 - loss: 0.0590 - precision_3: 0.9926 - recall_3: 0.9907 - top_2_categorical_accuracy: 0.9948 - val_accuracy: 0.9908 - val_loss: 0.0273 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.9856 - loss: 0.0712 - precision_3: 0.9913 - recall_3: 0.9848 - top_2_categorical_accuracy: 0.9907 - val_accuracy: 0.9908 - val_loss: 0.0261 - val_precision_3: 0.9908 - val_recall_3: 0.9908 - val_top_2_categorical_accuracy: 1.0000 - learning_rate: 0.0010
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 753ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win30/_win30:
# Training Time: 0:57:44.799409
# Validation Accuracy: 0.9907834101382489
# Test Accuracy: 0.981549815498155
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.92      1.00      0.96        22
#         video       1.00      0.98      0.99        43
# file transfer       1.00      1.00      1.00       126
#          chat       1.00      0.96      0.98        26
#
#      accuracy                           0.99       217
#     macro avg       0.98      0.98      0.98       217
#  weighted avg       0.99      0.99      0.99       217
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       0.96      1.00      0.98        27
#         video       1.00      0.95      0.97        59
# file transfer       0.99      0.99      0.99       154
#          chat       0.91      1.00      0.95        31
#
#      accuracy                           0.98       271
#     macro avg       0.97      0.98      0.97       271
#  weighted avg       0.98      0.98      0.98       271
#
# --------------------------------------------------------------------------------
# Evaluating dataset: _win10 from directory: /kaggle/input/vpn-non-vpn-iscx-2016-npy/win10
# Conv Layers: [(10, (10, 10), 5), (20, (10, 10), 5)]
# Dropout Rates: [0.25, 0.5]
# Dense Layers: [64]
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 187s 19s/step - accuracy: 0.2625 - loss: 1.3772 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - top_2_categorical_accuracy: 0.6783 - val_accuracy: 0.2024 - val_loss: 1.3134 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_top_2_categorical_accuracy: 0.9292 - learning_rate: 0.0010
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 187s 19s/step - accuracy: 0.3298 - loss: 1.2974 - precision_4: 0.5938 - recall_4: 0.0295 - top_2_categorical_accuracy: 0.8819 - val_accuracy: 0.5750 - val_loss: 0.9396 - val_precision_4: 0.7595 - val_recall_4: 0.1012 - val_top_2_categorical_accuracy: 0.9831 - learning_rate: 0.0010
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.6222 - loss: 1.0851 - precision_4: 0.6998 - recall_4: 0.3975 - top_2_categorical_accuracy: 0.9682 - val_accuracy: 0.9039 - val_loss: 0.4981 - val_precision_4: 1.0000 - val_recall_4: 0.7487 - val_top_2_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.8675 - loss: 0.8190 - precision_4: 0.9693 - recall_4: 0.6965 - top_2_categorical_accuracy: 0.9691 - val_accuracy: 0.9022 - val_loss: 0.2980 - val_precision_4: 1.0000 - val_recall_4: 0.7841 - val_top_2_categorical_accuracy: 0.9815 - learning_rate: 0.0010
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.8983 - loss: 0.6479 - precision_4: 0.9961 - recall_4: 0.7687 - top_2_categorical_accuracy: 0.9855 - val_accuracy: 0.9207 - val_loss: 0.2291 - val_precision_4: 1.0000 - val_recall_4: 0.8078 - val_top_2_categorical_accuracy: 0.9848 - learning_rate: 0.0010
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.9144 - loss: 0.5191 - precision_4: 0.9884 - recall_4: 0.8114 - top_2_categorical_accuracy: 0.9778 - val_accuracy: 0.9309 - val_loss: 0.1812 - val_precision_4: 0.9980 - val_recall_4: 0.8533 - val_top_2_categorical_accuracy: 0.9848 - learning_rate: 0.0010
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.9238 - loss: 0.4256 - precision_4: 0.9793 - recall_4: 0.8631 - top_2_categorical_accuracy: 0.9839 - val_accuracy: 0.9292 - val_loss: 0.1559 - val_precision_4: 0.9981 - val_recall_4: 0.8651 - val_top_2_categorical_accuracy: 0.9865 - learning_rate: 0.0010
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 19s/step - accuracy: 0.9094 - loss: 0.3691 - precision_4: 0.9343 - recall_4: 0.8864 - top_2_categorical_accuracy: 0.9849 - val_accuracy: 0.9359 - val_loss: 0.1305 - val_precision_4: 0.9821 - val_recall_4: 0.9275 - val_top_2_categorical_accuracy: 0.9899 - learning_rate: 0.0010
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 18s/step - accuracy: 0.9075 - loss: 0.3875 - precision_4: 0.9194 - recall_4: 0.8918 - top_2_categorical_accuracy: 0.9821 - val_accuracy: 0.9359 - val_loss: 0.1190 - val_precision_4: 0.9534 - val_recall_4: 0.9325 - val_top_2_categorical_accuracy: 0.9899 - learning_rate: 0.0010
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 19s/step - accuracy: 0.9203 - loss: 0.3328 - precision_4: 0.9366 - recall_4: 0.9098 - top_2_categorical_accuracy: 0.9798 - val_accuracy: 0.9376 - val_loss: 0.1106 - val_precision_4: 0.9423 - val_recall_4: 0.9359 - val_top_2_categorical_accuracy: 0.9916 - learning_rate: 0.0010
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 189s 19s/step - accuracy: 0.9149 - loss: 0.2909 - precision_4: 0.9283 - recall_4: 0.9078 - top_2_categorical_accuracy: 0.9843 - val_accuracy: 0.9865 - val_loss: 0.1020 - val_precision_4: 0.9948 - val_recall_4: 0.9730 - val_top_2_categorical_accuracy: 0.9933 - learning_rate: 0.0010
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 18s/step - accuracy: 0.9475 - loss: 0.2386 - precision_4: 0.9594 - recall_4: 0.9406 - top_2_categorical_accuracy: 0.9895 - val_accuracy: 0.9427 - val_loss: 0.0976 - val_precision_4: 0.9441 - val_recall_4: 0.9393 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 185s 19s/step - accuracy: 0.9474 - loss: 0.2449 - precision_4: 0.9516 - recall_4: 0.9372 - top_2_categorical_accuracy: 0.9919 - val_accuracy: 0.9899 - val_loss: 0.0842 - val_precision_4: 0.9949 - val_recall_4: 0.9848 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9635 - loss: 0.2250 - precision_4: 0.9683 - recall_4: 0.9554 - top_2_categorical_accuracy: 0.9878 - val_accuracy: 0.9949 - val_loss: 0.0757 - val_precision_4: 0.9949 - val_recall_4: 0.9916 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 180s 18s/step - accuracy: 0.9655 - loss: 0.2057 - precision_4: 0.9774 - recall_4: 0.9579 - top_2_categorical_accuracy: 0.9911 - val_accuracy: 0.9949 - val_loss: 0.0683 - val_precision_4: 0.9949 - val_recall_4: 0.9949 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 18s/step - accuracy: 0.9821 - loss: 0.1570 - precision_4: 0.9856 - recall_4: 0.9803 - top_2_categorical_accuracy: 0.9951 - val_accuracy: 0.9916 - val_loss: 0.0589 - val_precision_4: 0.9932 - val_recall_4: 0.9916 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 183s 19s/step - accuracy: 0.9830 - loss: 0.1419 - precision_4: 0.9856 - recall_4: 0.9811 - top_2_categorical_accuracy: 0.9890 - val_accuracy: 0.9949 - val_loss: 0.0528 - val_precision_4: 0.9949 - val_recall_4: 0.9949 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 181s 18s/step - accuracy: 0.9824 - loss: 0.1221 - precision_4: 0.9852 - recall_4: 0.9806 - top_2_categorical_accuracy: 0.9926 - val_accuracy: 0.9933 - val_loss: 0.0480 - val_precision_4: 0.9933 - val_recall_4: 0.9933 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 182s 18s/step - accuracy: 0.9857 - loss: 0.1007 - precision_4: 0.9864 - recall_4: 0.9857 - top_2_categorical_accuracy: 0.9902 - val_accuracy: 0.9949 - val_loss: 0.0431 - val_precision_4: 0.9949 - val_recall_4: 0.9933 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 182s 18s/step - accuracy: 0.9846 - loss: 0.1095 - precision_4: 0.9846 - recall_4: 0.9846 - top_2_categorical_accuracy: 0.9913 - val_accuracy: 0.9933 - val_loss: 0.0394 - val_precision_4: 0.9933 - val_recall_4: 0.9933 - val_top_2_categorical_accuracy: 0.9949 - learning_rate: 0.0010
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 756ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 785ms/step
# Results for /kaggle/input/vpn-non-vpn-iscx-2016-npy/win10/_win10:
# Training Time: 1:00:57.702920
# Validation Accuracy: 0.9932546374367622
# Test Accuracy: 0.9946018893387314
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#          voip       1.00      0.97      0.98        33
#         video       1.00      0.98      0.99       120
# file transfer       1.00      1.00      1.00       384
#          chat       0.93      1.00      0.97        56
#
#      accuracy                           0.99       593
#     macro avg       0.98      0.99      0.99       593
#  weighted avg       0.99      0.99      0.99       593
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#          voip       1.00      1.00      1.00        51
#         video       1.00      0.99      0.99       164
# file transfer       1.00      1.00      1.00       440
#          chat       0.96      1.00      0.98        86
#
#      accuracy                           0.99       741
#     macro avg       0.99      1.00      0.99       741
#  weighted avg       0.99      0.99      0.99       741
#
# --------------------------------------------------------------------------------
